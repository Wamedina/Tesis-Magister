# %%
import sys  
sys.path.insert(0, '../BendersProblems/')

# %%
import pandas as pd

# %%
path = "/home/williams/Tesis-Magister/Databases/"
rebloggedDatabase = 'Modelo_F_OG_4_4_4.xlsx'
database = 'Modelo_F_OG.xlsx'
elValle = 'elvalle.csv'

# %%
rebloggedMineDataframe = pd.read_excel(path + rebloggedDatabase, engine="openpyxl") #Notebook
mineDataframe = pd.read_excel(path + database, engine="openpyxl") #Notebook

# %%
elValleDataframe = pd.read_csv(path + elValle)

# %%
rebloggedMineDataframe
# Out:
#        Bloque     X     Y     Z     Ton  Mineral  %Cu  CMina CA  CPlanta CA  \
# 0           0   145   265   745  172800        0  0.0   10.4265           7
# 1           1   185   265   745  172800        0  0.0   10.4265           7
# 2           2   225   265   745  172800        0  0.0   10.4265           7
# 3           3   265   265   745  172800        0  0.0   10.4265           7
# 4           4   305   265   745  172800        0  0.0   10.4265           7
# ...       ...   ...   ...   ...     ...      ...  ...       ...         ...
# 11755   11755  1065  1345  1305  172800        0  0.0    9.5865           7
# 11756   11756  1105  1345  1305  172800        0  0.0    9.5865           7
# 11757   11757  1145  1345  1305  172800        0  0.0    9.5865           7
# 11758   11758  1185  1345  1305  172800        0  0.0    9.5865           7
# 11759   11759  1225  1345  1305  172800        0  0.0    9.5865           7
#
#        Recuperación
# 0               0.7
# ...

# %%
elValleDataframe.rename({"xcentre": "X", "ycentre": "Y", "zcentre": "Z",  })
# Out:
#         xcentre  ycentre  zcentre  xlength  ylength  zlength  volume  \
# 0        2510.0   3550.0   1508.0     20.0     20.0     18.0  7200.0
# 1        2510.0   3570.0   1508.0     20.0     20.0     18.0  7200.0
# 2        2510.0   3590.0   1508.0     20.0     20.0     18.0  7200.0
# 3        2530.0   3550.0   1508.0     20.0     20.0     18.0  7200.0
# 4        2550.0   3550.0   1508.0     20.0     20.0     18.0  7200.0
# ...         ...      ...      ...      ...      ...      ...     ...
# 130195   3910.0   4150.0   2498.0     20.0     20.0     18.0  7200.0
# 130196   3930.0   4150.0   2498.0     20.0     20.0     18.0  7200.0
# 130197   3950.0   4150.0   2498.0     20.0     20.0     18.0  7200.0
# 130198   3970.0   4150.0   2498.0     20.0     20.0     18.0  7200.0
# 130199   3990.0   4150.0   2498.0     20.0     20.0     18.0  7200.0
#
#              cuco  dens  ley_cus   ley_cut    ley_mo      recmo       recu  \
# ...

# %%
elValleDataframe.columns
# Out:
# Index(['xcentre', 'ycentre', 'zcentre', 'xlength', 'ylength', 'zlength',
#        'volume', 'cuco', 'dens', 'ley_cus', 'ley_cut', 'ley_mo', 'recmo',
#        'recu', 'topo_pnd_2018'],
#       dtype='object')
