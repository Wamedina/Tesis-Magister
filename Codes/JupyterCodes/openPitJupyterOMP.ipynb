# %%
import sys  
sys.path.insert(0, '../AuxiliarCodes/')

# %%
from   gurobipy   import GRB
from globalFunctions import getNumberOfBlocksInADimension
from openPitFunctions import finalBlock
import gurobipy   as     gp
import pandas as pd
import re
import subprocess as sp
import random

# %%
#path = "C:/Users/willi/OneDrive/Escritorio/Magister/Tesis-Magister/Database/integratedModel/" #Notebook
path = "/home/williams/Tesis-Magister/Databases/"
#path = "C:/Users/Williams Medina/Desktop/Tesis Magister/Tesis-Magister/ThesisCode/MainCode/Databases/integratedModel/" #Desktop
#openPitDatabaseName = 'Modelo_F_OG.xlsx'
openPitDatabaseName = 'Modelo_F_OG_4_4_4.xlsx'

# %%
openPitDataframe = pd.read_excel(path + openPitDatabaseName, engine="openpyxl") #Notebook

# %%
#Falta agregar la restricción GQC_Up_OP y GQC_low_OP
#Dejar como indice, valor (formulario de función objetivo), duracion,tonelaje bloque, tonelaje * % Cu
#./omp.sh /home/williams/Tesis-Magister/ThesisCode/BendersCode/openPit/files/openPit.* /home/williams/Tesis-Magister/ThesisCode/BendersCode/openPit/params/openPit.params
#./omp.sh ./openPit/files/openPit.* ./openPit/params/openPit.params

#1 periodo como defecto

# %%
class OpenPitModel:
   def __init__(self, database, numberOfPeriods):
      self.database = database
      self.numberOfPeriods = numberOfPeriods
      self.numberOfDestinations = 1
      self.basePrice = 3791.912
      self.desc = 0.1

   def execute(self):
      self.setOpenPitVariables()
      self.getOpenPitInfo()
      self.setOpenPitParameters()
      self.setOpenPitMineLimits()
      self.createOmpInput()
      return (self.executeOmp())
      #self.setFinalParameters()

   def setOpenPitVariables(self):
      self.openPitBlocksLength = self.database['X'].to_dict() 
      self.openPitBlocksWidth = self.database['Y'].to_dict() 
      self.openPitBlocksHeight = self.database['Z'].to_dict() #Los bloques se orientan de abajo hacia arriba, el bloque 0 es el que esta más abajo, 784 bloques
      self.L_b = self.database['Ton'].to_dict() #openPitBlockTonnage
      self.o_b = self.database['Mineral'].to_dict() #openPitBlockMineral
      self.openPitBlockRecovery = self.database['Recuperación'].to_dict() #openPitBlockRecovery
      self.openPitCopperLaw = self.database['%Cu'].to_dict() #openPitCopperLaw
      self.c_pbt = self.database['CPlanta CA'].to_dict() #openPitPlantCapacity
      self.c_mbt = self.database['CMina CA'].to_dict() #openPitMineCapacity

   def getOpenPitInfo(self):
      self.openPitBlocks = [i for i in range(len(self.openPitBlocksLength.values()))]

   def setOpenPitParameters(self):
      #OpenPit Parameters
      self.t_C   = {period : period + 1 for period in range(self.numberOfPeriods)}
      self.RMu_t = {period : 13219200.0 for period in range(self.numberOfPeriods)}#Superior infinita, 0 por abajo Originales: 13219200
      self.RMl_t = {period : 8812800.0 for period in range(self.numberOfPeriods)}#Valor original 8812800.0
      self.RPu_t = {period : 10933380.0 for period in range(self.numberOfPeriods)}#Valor original 10933380.0
      self.RPl_t = {period : 0 for period in range(self.numberOfPeriods)}#Valor original 7288920.0 
      self.qu_t  = {period : 1 for period in range(self.numberOfPeriods)}#Leyes promedio maxima y minima.
      self.ql_t  = {period : 0.15 for period in range(self.numberOfPeriods)}
      self.delta = {period: 0 for period in range(self.numberOfPeriods)}
      self.maxTimeOpenPit = self.t_C[max(self.t_C)]

   def setOpenPitMineLimits(self):
      self.openPitBlocksLengthLimits = getNumberOfBlocksInADimension(self.openPitBlocksLength)
      self.openPitBlocksWidthLimits = getNumberOfBlocksInADimension(self.openPitBlocksWidth)
      self.openPitBlocksHeightLimits = getNumberOfBlocksInADimension(self.openPitBlocksHeight)
      self.predecessorBlock = self.setPredecessorBlocks()

   def setModelAndGetResults(self):
      self.objValue, self.variableValues, self.runtime, self.gap = self.openPitModel()

   def setPredecessorBlocks(self):
      self.predecessorBlocks = finalBlock(self.openPitBlocks, self.openPitBlocksLengthLimits,self.openPitBlocksWidthLimits, self.openPitBlocksHeightLimits)

   def createOmpInput(self):
      self.writeProblemFile()
      self.writeBlocksFile()
      self.writePrecFile()
      self.writeParamsFile()
   
   def writeProblemFile(self):
      with open('../FilesToExecuteOmpOpenPit/files/openPit.prob', 'w') as f:
         numberOfDestinations = 'NDESTINATIONS: ' + str(self.numberOfDestinations)
         numberOfPeriods = 'NPERIODS: ' + str(self.numberOfPeriods)
         objective = 'OBJECTIVE: 0 1'
         duration = 'DURATION: 2'
         discountRate = 'DISCOUNT_RATE: '+ str(self.desc)#/self.numberOfPeriods)
         
         tonUpConstraint = 'CONSTRAINT: 0 3 P * L '
         for rmu in self.RMu_t.values():
            tonUpConstraint +=str(rmu) + " "

         tonLowContraint = 'CONSTRAINT: 1 3 P * G '
         for rml in self.RMl_t.values():
            tonLowContraint +=str(rml) + " "
         
         matUpConstraint = 'CONSTRAINT: 2 4 P * L '
         for rpu in self.RPu_t.values():
            matUpConstraint +=str(rpu) + " "

         matLowConstraint = 'CONSTRAINT: 3 4 P * G '
         for rpl in self.RPl_t.values():
            matLowConstraint +=str(rpl) + " "
         
         copperLawUpConstraint = 'CONSTRAINT: 4 5 P * L ' 
         for qut in self.qu_t.values():
            copperLawUpConstraint +=str(qut*sum(self.L_b.values())) + " "

         copperLawLowConstraint = 'CONSTRAINT: 5 5 P * G '
         for qlt in self.ql_t.values():
            copperLawLowConstraint +=str(qlt*sum(self.L_b.values())) + " "

         infeasibleBlocks = 'CONSTRAINT: 6 6 P * L '
         for delta in self.delta.values():
            infeasibleBlocks +=str(delta) + " "
         constraints = [tonUpConstraint, tonLowContraint, matUpConstraint, matLowConstraint, copperLawUpConstraint,copperLawLowConstraint,infeasibleBlocks]
         self.numberOfConstraints = len(constraints)
         self.nConstraints = 'NCONSTRAINTS: ' + str(self.numberOfConstraints)
         f.write('{}\n{}\n{}\n{}\n{}\n{}\n'.format(numberOfDestinations,numberOfPeriods, objective,duration,discountRate,self.nConstraints))
         f.write('{}\n{}\n{}\n{}\n{}\n{}\n{}\n'.format(*constraints))

   def writeBlocksFile(self):
      with open('../FilesToExecuteOmpOpenPit/files/openPit.blocks', 'w') as f:
         for block in self.openPitBlocks:
            index = block
            value = ((self.basePrice*self.openPitCopperLaw[block]-self.c_pbt[block])*self.o_b[block])-(self.c_mbt[block]*self.L_b[block])
            duration = 1
            ton = self.L_b[block]
            mineral = self.o_b[block]
            copperLaw = self.openPitCopperLaw[block] * self.L_b[block]
            #1 si no se puede extraer, 10977 última capa, los bloques van de abajo hacia arriba, 0 primer bloque de abajo, 10977 última capa hacia arriba, con 10975 la sol es vacia
            if block < 5902:
               f.write(('{} {} {} {} {} {} {}\n').format(index, value, duration,ton, mineral,copperLaw, 1))
            else:
               f.write(('{} {} {} {} {} {} {}\n').format(index, value, duration,ton, mineral,copperLaw, 0))
                 
   def writePrecFile(self):
      with open('../FilesToExecuteOmpOpenPit/files/openPit.prec', 'w') as f:
         for index,blockList in enumerate(self.predecessorBlocks):
            predecessorLine = str(len(blockList))
            for block in blockList:
               if block == index:
                  predecessorLine = " 0"
                  break
               else:
                  predecessorLine +=" " + str(block)
            f.write("{} {}\n".format(index, predecessorLine))
            
   def writeParamsFile(self):
      with open('../FilesToExecuteOmpOpenPit/params/openPit.params', 'w') as f:
         f.write("""USE_DISPLAY: 1
WRITE.LP.SOLUTION: 1
WRITE.IP.SOLUTION: 1
CPIT: 1
PP.ULTIMATE_PIT: 1
PP.FORCE_UPIT: 1
PP.EARLY_START: 1
PP.WASTE_OPTION: 1
PP.ELIM_NULL: 0
PP.TRANSITIVE_REDUCTION: 0
AG.USE_BLOCK_AGGREGATION: 0
AG.BLOCK_AGGREGATION: 0
OPTMETHOD: 0
CG.ONE_DESTINATION: 1
CG.IMPLICIT: 0
CG.USE_DISPLAY: 1
CG.MAX_ITER: -1
CG.TARGET_GAP: 0.0001
CG.MAX_TIME: -1
CG.USE_KSTEP: 0
CG.KSTEP_K: 10
CG.MASTER_NTHREADS: 4
CG.DISPLAY_DUALS: 1
HE.TOPOSORT: 1
HE.FTOPOSORT: 0
HE.NALPHA_POINTS: 50
HE.OPT_DESTINATIONS: 1
HE.NAIVE: 0
HE.NAIVE_INTSOLLIM: 1000
HE.NAIVE_EPGAP: 0.01
HE.NAIVE_TILIM: 14400
CP.DYNAMIC_CUTS: 0
CP.CLIQUES: 0
CP.MINW: 0
CP.DELAYED_PRECEDENCES: 0
CONSTRAINT_PROGRAMMING: 0
CPROG.GAP_LIMIT: 0.01
CPROG.CP_TIME_LIMIT: 28800
CPROG.EX_TIME_LIMIT: 28800
CPROG.HOT_START: 1
CPROG.NTHREADS: 8""")

   def executeOmp(self):
      output = sp.getoutput("./omp.sh ../FilesToExecuteOmpOpenPit/files/openPit.* ../FilesToExecuteOmpOpenPit/params/dbs_duals.params")
      print(output)
      return(output)
      #return self.getPiAndObjectiveValue(output)
   
   def getPiAndObjectiveValue(self, output, isFinalIteration):
      objective_value_to_use = 0
      if isFinalIteration:
         objective_value_to_use = 1
      pi_positions = [positions.start() for positions in re.finditer("rhs= 0.000000", output)]
      pi_t = dict.fromkeys(self.t_C,0)
      for pos in pi_positions:
         pi_value = float(output[pos-48: pos].split()[-3])
         pi_index = float(output[pos-48: pos].split()[-5])
         period_index = pi_index - self.numberOfPeriods * (self.numberOfConstraints - 1)
         pi_t[period_index] = pi_value

      objective_value_positions = [positions.start() for positions in re.finditer("Objective Value ", output)]
      objective_value = float(output[objective_value_positions[objective_value_to_use]: objective_value_positions[objective_value_to_use]+100].split()[-3])
      return objective_value, pi_t

# %%
numberOfPeriods = 5
openPitModel = OpenPitModel(openPitDataframe,numberOfPeriods)
#pi_vb, obective_value = openPitModel.execute()
#pi_vb, obective_value 
output = openPitModel.execute()
# Out:
# Running OMP version: master 1.8.5 d7d16093 2022-11-16 20:03:46 -0300
# Invoked using: bin/OMP_SOLVER_C1290 ../FilesToExecuteOmpOpenPit/files/openPit.blocks ../FilesToExecuteOmpOpenPit/files/openPit.prec ../FilesToExecuteOmpOpenPit/files/openPit.prob ../FilesToExecuteOmpOpenPit/params/dbs_duals.params
# license to sign [DEFAULTclient-signatureAFhG-4bsA-AAA=lic_ver200valid-to2023-03-07]
# LICENSE OK!
# BLOCKS FILE: ../FilesToExecuteOmpOpenPit/files/openPit.blocks
# PREC FILE: ../FilesToExecuteOmpOpenPit/files/openPit.prec
# PROB FILE: ../FilesToExecuteOmpOpenPit/files/openPit.prob
# PARAMS FILE: ../FilesToExecuteOmpOpenPit/params/dbs_duals.params
# OR Solver: key created. The key is: openPit_openPit_dbs_duals
# STATS_INPUT_NAME openPit_openPit_dbs_duals
# OR Solver: loaded params (params file) OK.
# STATS_PARAM_STOCHASTIC_MODE 0
# Objective: NPV
# DURATION loaded from column 2.
# Loaded prob file OK.
# Loaded block file columns OK.
# Vars and Prob populated OK.
# Block memory allocated OK.
# Block information in VARS populated OK.
# Bin information in VARS populated OK.
# dbldata OK.
# intdata OK.
# stockpiles OK.
# objfunction OK.
# objcols OK.
# Cleanup OK.
# OR Solver: loaded problem (prob and block files) OK.
# NNODES = 11760
# OR Solver: created arcs.
# STATS_INPUT_LOAD_TIME 0.009406
# EARLY START / TMIN PROPAGATION ELIMINATED 0 TIME PERIODS
# No bins eliminated due to propagation.
#
# ****************************
# ACTIVATED FEATURES:
# ****************************
# USE INPUT SOLUTION      : No
# USE PREPROCESSING       : Yes
# USE AGGREGATION         : No
# USE CUTTING PLANES      : No
# USE PRECOMPUTED COLUMNS : Yes
# SOLVE LP RELAXATION     : Yes
# USE HEURISTICS          : Yes
# USE BRANCH-AND-BOUND    : No
# ****************************
#
# ************************ INPUT DATA TESTING ************************
#
# RRCNT = 7
#
# INPUT DATA:
#
# nblocks=11760, nbins=11760, nperiods=5, ndestinations=1, nyvars=0, avg_nblockperiods=5.0, avg_nblockdestinations=1.0,  avg_nblocksinbin=1.0, narcs=53312,
# discount_rate=0.100000, rowcnt=7, sink_rate=0, phase_rate=0, max_open_benches=-1, nscenarios=0
# natvars (nidx) = 58800
# STATS_INPUT_NBLOCKS 11760
# STATS_INPUT_NBINS 11760
# STATS_INPUT_NPERIODS 5
# STATS_INPUT_SCENARIOS 0
# STATS_INPUT_NXVARS 58800
# STATS_INPUT_NYVARS 58800
# STATS_INPUT_NARCS 53312
# STATS_DISCOUNT_RATE 0.100000
#
# Done with input data testing in 0.000625 seconds. Time elapsed: 0.000632 in orsolver_internal (/home/nloira/projects/OMP/src/orsolver.c:277)
#
# ************************** PRE-PROCESSING **************************
#
# PP-ITERATION: 1
# ULTIMATE-PIT = Yes.
# UPIT value in Pre-Processing: 1487495320.073983, by elimimnating 10297 blocks. in ultimate_pit_pp (/home/nloira/projects/OMP/src/or_preprocess.c:179)
#     Problem qualifies for UPIT = Yes. in orsolver_internal (/home/nloira/projects/OMP/src/orsolver.c:484)
#     Number of bins eliminated = 10297. in orsolver_internal (/home/nloira/projects/OMP/src/orsolver.c:485)
# STATS_PPITER_UPIT_NBINS_REMOVED 10297
# STATS_PPITER_UPIT_NXVARS_REMOVED 51485
# WASTE-OPTION = Yes.
#     Number of block-destinations eliminated = 0. in orsolver_internal (/home/nloira/projects/OMP/src/orsolver.c:519)
# STATS_PPITER_MODEELIMINATION_NYVARS_REMOVED 0
# CAPACITY EARLY STARTS = Yes.
#     Number of bins eliminated = 85. in orsolver_internal (/home/nloira/projects/OMP/src/orsolver.c:576)
#     Number of additional bin-periods eliminated = 756. in orsolver_internal (/home/nloira/projects/OMP/src/orsolver.c:577)
# STATS_PPITER_EARLYSTARTS_NXVARS_REMOVED 1181
# STATS_PPITER_EARLYSTARTS_NYVARS_REMOVED 1181
# REMOVE NULL BINS = No .
# TRANSITIVE_REDUCTION = No .
# PP-ITERATION: 2
# ULTIMATE-PIT = Yes.
# UPIT value in Pre-Processing: 1188811301.309274, by elimimnating 530 blocks. in ultimate_pit_pp (/home/nloira/projects/OMP/src/or_preprocess.c:179)
#     Problem qualifies for UPIT = Yes. in orsolver_internal (/home/nloira/projects/OMP/src/orsolver.c:484)
#     Number of bins eliminated = 530. in orsolver_internal (/home/nloira/projects/OMP/src/orsolver.c:485)
# STATS_PPITER_UPIT_NBINS_REMOVED 530
# STATS_PPITER_UPIT_NXVARS_REMOVED 2240
# WASTE-OPTION = Yes.
#     Number of block-destinations eliminated = 0. in orsolver_internal (/home/nloira/projects/OMP/src/orsolver.c:519)
# STATS_PPITER_MODEELIMINATION_NYVARS_REMOVED 0
# CAPACITY EARLY STARTS = Yes.
#     Number of bins eliminated = 0. in orsolver_internal (/home/nloira/projects/OMP/src/orsolver.c:576)
#     Number of additional bin-periods eliminated = 0. in orsolver_internal (/home/nloira/projects/OMP/src/orsolver.c:577)
# STATS_PPITER_EARLYSTARTS_NXVARS_REMOVED 0
# STATS_PPITER_EARLYSTARTS_NYVARS_REMOVED 0
# REMOVE NULL BINS = No .
# TRANSITIVE_REDUCTION = No .
# PP-ITERATION: 3
# ULTIMATE-PIT = Yes.
# UPIT value in Pre-Processing: 1188811301.309274, by elimimnating 0 blocks. in ultimate_pit_pp (/home/nloira/projects/OMP/src/or_preprocess.c:179)
#     Problem qualifies for UPIT = Yes. in orsolver_internal (/home/nloira/projects/OMP/src/orsolver.c:484)
#     Number of bins eliminated = 0. in orsolver_internal (/home/nloira/projects/OMP/src/orsolver.c:485)
# STATS_PPITER_UPIT_NBINS_REMOVED 0
# STATS_PPITER_UPIT_NXVARS_REMOVED 0
# WASTE-OPTION = Yes.
#     Number of block-destinations eliminated = 0. in orsolver_internal (/home/nloira/projects/OMP/src/orsolver.c:519)
# STATS_PPITER_MODEELIMINATION_NYVARS_REMOVED 0
# CAPACITY EARLY STARTS = Yes.
#     Number of bins eliminated = 0. in orsolver_internal (/home/nloira/projects/OMP/src/orsolver.c:576)
#     Number of additional bin-periods eliminated = 0. in orsolver_internal (/home/nloira/projects/OMP/src/orsolver.c:577)
# STATS_PPITER_EARLYSTARTS_NXVARS_REMOVED 0
# STATS_PPITER_EARLYSTARTS_NYVARS_REMOVED 0
# REMOVE NULL BINS = No .
# TRANSITIVE_REDUCTION = No .
# STATS_PP_NITERATIONS 3
# STATS_PP_UPIT_NBINS_REMOVED 10827
# STATS_PP_UPIT_NXVARS_REMOVED 53725
# STATS_PP_EARLYSTARTS_NXVARS_REMOVED 1181
# STATS_PP_EARLYSTARTS_NYVARS_REMOVED 1181
# STATS_PP_MODEELIMINATION_NYVARS_REMOVED 0
# STATS_PP_NULLBINS_NXVARS_REMOVED 0
# STATS_PP_NULLBINS_NYVARS_REMOVED 0
# STATS_PP_NULLBINS_NARCS_ADDED 0
# STATS_PP_TRANSITIVEREDUCTION_NARCS_REMOVED 0
# STATS_PP_NXVARS_REMOVED 54906
# STATS_PP_NYVARS_REMOVED 54906
# STATS_PP_NARCS_REMOVED 50162
# STATS_PP_TIME 0.004062
#
# Done with preprocessing in 0.005351 seconds Time elapsed: 0.005984 in orsolver_internal (/home/nloira/projects/OMP/src/orsolver.c:705)
#
# *************************** AGGREGATION ****************************
#
# BLOCK_AGGREGATION = No .
#
# Done with aggregation in 0.000001 seconds. Time elapsed: 0.005986 in orsolver_internal (/home/nloira/projects/OMP/src/orsolver.c:750)
#
# ******************* INITIALIZING DATA STRUCTURES *******************
#
# RRCNT = 7
# BY-LP problem created. It has 3894 variables, 17066 precedence constraints, 35 resource constraints and 35560 non-zero coefficients in the resource constraints. in orsolver_internal (/home/nloira/projects/OMP/src/orsolver.c:867)
#
# PREPROCESSED AND AGGREGATED DATA:
#
# nblocks=848, nbins=848, nperiods=5, ndestinations=1, nyvars=0, avg_nblockperiods=4.6, avg_nblockdestinations=1.0,  avg_nblocksinbin=1.0, narcs=3150,
# discount_rate=0.100000, rowcnt=7, sink_rate=0, phase_rate=0, max_open_benches=-1, nscenarios=0
# natvars (nidx) = 3894
#
# Done with input data testing in 0.000582 seconds. Time elapsed: 0.006570 in orsolver_internal (/home/nloira/projects/OMP/src/orsolver.c:891)
#
# ********************* ANALYZING INPUT SOLUTION *********************
#
# There is no input solution
#
# Done with input solution analysis in 0.000000 seconds. Time elapsed: 0.006573 in orsolver_internal (/home/nloira/projects/OMP/src/orsolver.c:1020)
#
# *********************** PRECOMPUTING COLUMNS ***********************
#
# CPIT starting-solution: Yes
# CPIT computed for constraint 0 obtaining a value of 692689920.719881
# Creating initial partition of size 7
# CPIT computed for constraint 1 obtaining a value of 289494149.192713
# Refinining initial partition, new size is 13
# CPIT computed for constraint 2 obtaining a value of 250494143.846992
# Refinining initial partition, new size is 16
# CPIT computed for constraint 3 obtaining a value of 0.000000
# Refinining initial partition, new size is 16
# CPIT computed for constraint 4 obtaining a value of 1188811301.309274
# Refinining initial partition, new size is 16
# CPIT computed for constraint 5 obtaining a value of 1171016435.333335
# Refinining initial partition, new size is 18
# CPIT computed for constraint 6 obtaining a value of 0.000000
# Refinining initial partition, new size is 18
# Starting with partition defined by CPIT.
#
# Done with hot start columns in 0.006549 seconds. Time elapsed: 0.013123 in orsolver_internal (/home/nloira/projects/OMP/src/orsolver.c:1093)
#
# ************************ PRECOMPUTING CUTS *************************
#
# Not using cuts
#
# Done with cuts in 0.000002 seconds. Time elapsed: 0.013127 in orsolver_internal (/home/nloira/projects/OMP/src/orsolver.c:1213)
#
# ***************************** LP-SOLVE *****************************
#
# OPTIMIZATION method: Bienstock-Zuckerberg.
#
# |-----+-----------+---------------------+--------------------+-----------+-----------+-----------+-----------+-----------+------------|
# | BIENSTOCK-ZUCKERBERG ALGORITHM: Target gap = 1.00e-04.  Target eps = 1.00e-06.  Starting phase = Phase  I.                          |
# | Number of variables: tot = 3929, x = 3894, y = 0, s = 35, Use step = 0 (10), kstep = 0, lstep = 0, xstep = 0 (-1)
# |-----+-----------+---------------------+--------------------+-----------+-----------+-----------+-----------+-----------+------------|
# |Iter.|#Part.     |    Primal Value     |  Lagrangian Value  |    Gap    | Pri. Time | Mas. Time | Tot. Time | Pri. Eps. |   Kappa    |
# |-----+-----------+---------------------+--------------------+-----------+-----------+-----------+-----------+-----------+------------|
# |   1 |   19   80 |            Phase  I |      1.0516447e+09 |  1.00e+00 |  0.000609 |  0.000897 |   0.00162 |  3.05e+08 |     32.619 |
# |   2 |   29  125 |            Phase IB |      1.1642371e+17 |  1.87e+04 |   0.00114 |   0.00125 |   0.00252 |  3.05e+08 |     31.741 |
# |   3 |   44  194 |            Phase IB |     -6.2404801e+12 |  2.58e-05 |   0.00186 |   0.00209 |    0.0041 |  3.05e+08 |     120.05 |
# |-----+-----------+---------------------+--------------------+-----------+-----------+-----------+-----------+-----------+------------|
# *   3 |   44  194 | Phase IB |    -1.7976931e+308 |  2.58e-05 |   0.00186 |   0.00209 |    0.0041 |     3e+08 |     120.05 | OMP_INFEASIBLE
# |-----+-----------+---------------------+--------------------+-----------+-----------+-----------+-----------+-----------+------------|
#
# PRINTING BZ DUAL INFORMATION
#
# BZ_DUAL: row= 0  pi= 23.418977  sense= L  rhs= 13219200.000000
# BZ_DUAL: row= 1  pi= 25.341654  sense= L  rhs= 13219200.000000
# BZ_DUAL: row= 2  pi= 25.357862  sense= L  rhs= 13219200.000000
# BZ_DUAL: row= 3  pi= 25.357862  sense= L  rhs= 13219200.000000
# BZ_DUAL: row= 4  pi= 25.357862  sense= L  rhs= 13219200.000000
# BZ_DUAL: row= 10  pi= 2.027477  sense= L  rhs= 10933380.000000
# BZ_DUAL: row= 34  pi= 4096.000000  sense= L  rhs= 0.000000
#
#
# STATS_BZ_NITERATIONS 3
# STATS_BZ_SOLVETIME 0.004554
# STATS_BZ_PRICINGTIME 0.001860
# STATS_BZ_MASTERTIME 0.002092
# STATS_BZ_NPARTITIONS 44
# STATS_NCUTS 0
# STATS_NCUT_ROUNDS 0
#
#
#           |------------------------------------------------------------|
#           |       BZ SOLUTION QUALITY INFORMATION                      |
#           |------------------------------------------------------------|
#           |                                | PP-AGG Sol  |  Orig Sol   |
#           |--------------------------------+-------------+-------------|
#           | Const. violation (max 3.0e+05) |  3.0473e+08 |  3.0473e+08 |
#           | Prec violation   (max 1.0e-05) |  0.0000e+00 |  0.0000e+00 |
#           | Bounds violation (max 1.0e-05) |  0.0000e+00 |  0.0000e+00 |
#           | Is Feasible?                   |     No      |     No      |
#           |--------------------------------+-------------+-------------|
#           | W. Int. Viol.    (max 1.0e-02) |  4.4288e-01 |  4.4288e-01 |
#           | S. Int. Viol.    (max 1.0e-02) |  4.9490e-01 |  4.9490e-01 |
#           | Is Integer (weak)?             |     No      |     No      |
#           | Is Integer (strong)?           |     No      |     No      |
#           |--------------------------------+-------------+-------------|
#           | Objective Value                |  6.6729e+08 |  6.6729e+08 |
#           |--------------------------------+-------------+-------------|
#           | Best Previous LP Solution      |-1.7977e+308 |-1.7977e+308 |
#           | Replace Best LP Solution?      |     No      |     Yes     |
#           |------------------------------------------------------------|
#           | Best Previous IP Solution      |-1.7977e+308 |-1.7977e+308 |
#           | Replace Best IP Solution?      |     No      |     No      |
#           |------------------------------------------------------------|
#             BZ SOLUTION written to openPit_openPit_dbs_duals.BZ.lp.sol
#
#           |------+------------------+---------+---------|
#           |  t   |    Objval[t]     | Perc[t] |  Acc[t] |
#           |------+------------------+---------+---------|
#           |    0 |   132650185.8764 |  19.88% |  19.88% |
#           |    1 |   117117946.6034 |  17.55% |  37.43% |
#           |    2 |   211516503.1427 |  31.70% |  69.13% |
#           |    3 |   107380738.5055 |  16.09% |  85.22% |
#           |    4 |    98624704.2191 |  14.78% | 100.00% |
#           |------+------------------+---------+---------|
#           | tot  |   667290078.3471 | 100.00% | 100.00% |
#           |------+------------------+---------+---------|
#
#
# |-----+--------------------------------+--------------------------------+--------------------------------|
# |  t  |         CONSTRAINT:  0         |         CONSTRAINT:  1         |         CONSTRAINT:  2         |
# |-----+--------------------------------+--------------------------------+--------------------------------|
# |   0 |   13219200.00 <=   13219200.00 |   13219200.00 >=    8812800.00 |   10933380.00 <=   10933380.00 |
# |   1 |   13219200.00 <=   13219200.00 |   13219200.00 >=    8812800.00 |   10599400.34 <=   10933380.00 |
# |   2 |   13219200.00 <=   13219200.00 |   13219200.00 >=    8812800.00 |   10933380.00 <=   10933380.00 |
# |   3 |   13219200.00 <=   13219200.00 |   13219200.00 >=    8812800.00 |    9022768.43 <=   10933380.00 |
# |   4 |   13219200.00 <=   13219200.00 |   13219200.00 >=    8812800.00 |    7428902.41 <=   10933380.00 |
# |-----+--------------------------------+--------------------------------+--------------------------------|
#
#
#
# Done with solving LP relaxation in 0.011009 seconds. Time elapsed: 0.024138 in orsolver_internal (/home/nloira/projects/OMP/src/orsolver.c:1553)
#
# ***************************** TOPOSORT *****************************
#
# TOPOSORT: Problem has all knapsack constraints. Proceeding with toposort algorithms.
# TOPOSORT: Use binary toposort = Yes.
# TOPOSORT: Use fractional toposort = No .
# TOPOSORT: Use mixed toposort = No .
# TOPOSORT: Use alpha-points toposort = Yes (nalpha_points=50).
# TOPOSORT: Use opt-destination = Yes.
# TOPOSORT: WARNING! Constraint 1 is not a knapsack constraint, so the solution of Toposort can be infeasible
# TOPOSORT: WARNING! Constraint 3 is not a knapsack constraint, so the solution of Toposort can be infeasible
# TOPOSORT: WARNING! Constraint 5 is not a knapsack constraint, so the solution of Toposort can be infeasible
# Running TOPOSORT with (1) Expected Time (2) Original obj.
# TOPOSORT: Toposort found solution with value 0.000000.
# TOPOSORT: Optimize destination fix previous solution with value 0.000000.
# Running TOPOSORT with (1) Expected Time (2) Discounted original obj.
# TOPOSORT: Toposort found solution with value 0.000000.
# TOPOSORT: Optimize destination fix previous solution with value 0.000000.
# Running TOPOSORT with (1) Expected Time (2) Duals from by
# TOPOSORT: Toposort found solution with value 0.000000.
# TOPOSORT: Optimize destination fix previous solution with value 0.000000.
# Running TOPOSORT with (1) Alpha points=0.020000 (2) Original obj.
# TOPOSORT: Toposort found solution with value 0.000000.
# TOPOSORT: Optimize destination fix previous solution with value 0.000000.
# Running TOPOSORT with (1) Alpha points=0.020000 (2) Discounted original obj.
# TOPOSORT: Toposort found solution with value 0.000000.
# TOPOSORT: Optimize destination fix previous solution with value 0.000000.
# Running TOPOSORT with (1) Alpha points=0.020000 (2) Duals from by
# TOPOSORT: Toposort found solution with value 0.000000.
# TOPOSORT: Optimize destination fix previous solution with value 0.000000.
# Running TOPOSORT with (1) Alpha points=0.040000 (2) Original obj.
# TOPOSORT: Toposort found solution with value 0.000000.
# TOPOSORT: Optimize destination fix previous solution with value 0.000000.
# Running TOPOSORT with (1) Alpha points=0.040000 (2) Discounted original obj.
# TOPOSORT: Toposort found solution with value 0.000000.
# TOPOSORT: Optimize destination fix previous solution with value 0.000000.
# Running TOPOSORT with (1) Alpha points=0.040000 (2) Duals from by
# TOPOSORT: Toposort found solution with value 0.000000.
# TOPOSORT: Optimize destination fix previous solution with value 0.000000.
# Running TOPOSORT with (1) Alpha points=0.060000 (2) Original obj.
# TOPOSORT: Toposort found solution with value 0.000000.
# TOPOSORT: Optimize destination fix previous solution with value 0.000000.
# Running TOPOSORT with (1) Alpha points=0.060000 (2) Discounted original obj.
# TOPOSORT: Toposort found solution with value 0.000000.
# TOPOSORT: Optimize destination fix previous solution with value 0.000000.
# Running TOPOSORT with (1) Alpha points=0.060000 (2) Duals from by
# TOPOSORT: Toposort found solution with value 0.000000.
# TOPOSORT: Optimize destination fix previous solution with value 0.000000.
# Running TOPOSORT with (1) Alpha points=0.080000 (2) Original obj.
# TOPOSORT: Toposort found solution with value 0.000000.
# TOPOSORT: Optimize destination fix previous solution with value 0.000000.
# Running TOPOSORT with (1) Alpha points=0.080000 (2) Discounted original obj.
# TOPOSORT: Toposort found solution with value 0.000000.
# TOPOSORT: Optimize destination fix previous solution with value 0.000000.
# Running TOPOSORT with (1) Alpha points=0.080000 (2) Duals from by
# TOPOSORT: Toposort found solution with value 0.000000.
# TOPOSORT: Optimize destination fix previous solution with value 0.000000.
# Running TOPOSORT with (1) Alpha points=0.100000 (2) Original obj.
# TOPOSORT: Toposort found solution with value 0.000000.
# TOPOSORT: Optimize destination fix previous solution with value 0.000000.
# Running TOPOSORT with (1) Alpha points=0.100000 (2) Discounted original obj.
# TOPOSORT: Toposort found solution with value 0.000000.
# TOPOSORT: Optimize destination fix previous solution with value 0.000000.
# Running TOPOSORT with (1) Alpha points=0.100000 (2) Duals from by
# TOPOSORT: Toposort found solution with value 0.000000.
# TOPOSORT: Optimize destination fix previous solution with value 0.000000.
# Running TOPOSORT with (1) Alpha points=0.120000 (2) Original obj.
# TOPOSORT: Toposort found solution with value 0.000000.
# TOPOSORT: Optimize destination fix previous solution with value 0.000000.
# Running TOPOSORT with (1) Alpha points=0.120000 (2) Discounted original obj.
# TOPOSORT: Toposort found solution with value 0.000000.
# TOPOSORT: Optimize destination fix previous solution with value 0.000000.
# Running TOPOSORT with (1) Alpha points=0.120000 (2) Duals from by
# TOPOSORT: Toposort found solution with value 0.000000.
# TOPOSORT: Optimize destination fix previous solution with value 0.000000.
# Running TOPOSORT with (1) Alpha points=0.140000 (2) Original obj.
# TOPOSORT: Toposort found solution with value 0.000000.
# TOPOSORT: Optimize destination fix previous solution with value 0.000000.
# Running TOPOSORT with (1) Alpha points=0.140000 (2) Discounted original obj.
# TOPOSORT: Toposort found solution with value 0.000000.
# TOPOSORT: Optimize destination fix previous solution with value 0.000000.
# Running TOPOSORT with (1) Alpha points=0.140000 (2) Duals from by
# TOPOSORT: Toposort found solution with value 0.000000.
# TOPOSORT: Optimize destination fix previous solution with value 0.000000.
# Running TOPOSORT with (1) Alpha points=0.160000 (2) Original obj.
# TOPOSORT: Toposort found solution with value 0.000000.
# TOPOSORT: Optimize destination fix previous solution with value 0.000000.
# Running TOPOSORT with (1) Alpha points=0.160000 (2) Discounted original obj.
# TOPOSORT: Toposort found solution with value 0.000000.
# TOPOSORT: Optimize destination fix previous solution with value 0.000000.
# Running TOPOSORT with (1) Alpha points=0.160000 (2) Duals from by
# TOPOSORT: Toposort found solution with value 0.000000.
# TOPOSORT: Optimize destination fix previous solution with value 0.000000.
# Running TOPOSORT with (1) Alpha points=0.180000 (2) Original obj.
# TOPOSORT: Toposort found solution with value 0.000000.
# TOPOSORT: Optimize destination fix previous solution with value 0.000000.
# Running TOPOSORT with (1) Alpha points=0.180000 (2) Discounted original obj.
# TOPOSORT: Toposort found solution with value 0.000000.
# TOPOSORT: Optimize destination fix previous solution with value 0.000000.
# Running TOPOSORT with (1) Alpha points=0.180000 (2) Duals from by
# TOPOSORT: Toposort found solution with value 0.000000.
# TOPOSORT: Optimize destination fix previous solution with value 0.000000.
# Running TOPOSORT with (1) Alpha points=0.200000 (2) Original obj.
# TOPOSORT: Toposort found solution with value 0.000000.
# TOPOSORT: Optimize destination fix previous solution with value 0.000000.
# Running TOPOSORT with (1) Alpha points=0.200000 (2) Discounted original obj.
# TOPOSORT: Toposort found solution with value 0.000000.
# TOPOSORT: Optimize destination fix previous solution with value 0.000000.
# Running TOPOSORT with (1) Alpha points=0.200000 (2) Duals from by
# TOPOSORT: Toposort found solution with value 0.000000.
# TOPOSORT: Optimize destination fix previous solution with value 0.000000.
# Running TOPOSORT with (1) Alpha points=0.220000 (2) Original obj.
# TOPOSORT: Toposort found solution with value 0.000000.
# TOPOSORT: Optimize destination fix previous solution with value 0.000000.
# Running TOPOSORT with (1) Alpha points=0.220000 (2) Discounted original obj.
# TOPOSORT: Toposort found solution with value 0.000000.
# TOPOSORT: Optimize destination fix previous solution with value 0.000000.
# Running TOPOSORT with (1) Alpha points=0.220000 (2) Duals from by
# TOPOSORT: Toposort found solution with value 0.000000.
# TOPOSORT: Optimize destination fix previous solution with value 0.000000.
# Running TOPOSORT with (1) Alpha points=0.240000 (2) Original obj.
# TOPOSORT: Toposort found solution with value 0.000000.
# TOPOSORT: Optimize destination fix previous solution with value 0.000000.
# Running TOPOSORT with (1) Alpha points=0.240000 (2) Discounted original obj.
# TOPOSORT: Toposort found solution with value 0.000000.
# TOPOSORT: Optimize destination fix previous solution with value 0.000000.
# Running TOPOSORT with (1) Alpha points=0.240000 (2) Duals from by
# TOPOSORT: Toposort found solution with value 0.000000.
# TOPOSORT: Optimize destination fix previous solution with value 0.000000.
# Running TOPOSORT with (1) Alpha points=0.260000 (2) Original obj.
# TOPOSORT: Toposort found solution with value 0.000000.
# TOPOSORT: Optimize destination fix previous solution with value 0.000000.
# Running TOPOSORT with (1) Alpha points=0.260000 (2) Discounted original obj.
# TOPOSORT: Toposort found solution with value 0.000000.
# TOPOSORT: Optimize destination fix previous solution with value 0.000000.
# Running TOPOSORT with (1) Alpha points=0.260000 (2) Duals from by
# TOPOSORT: Toposort found solution with value 0.000000.
# TOPOSORT: Optimize destination fix previous solution with value 0.000000.
# Running TOPOSORT with (1) Alpha points=0.280000 (2) Original obj.
# TOPOSORT: Toposort found solution with value 0.000000.
# TOPOSORT: Optimize destination fix previous solution with value 0.000000.
# Running TOPOSORT with (1) Alpha points=0.280000 (2) Discounted original obj.
# TOPOSORT: Toposort found solution with value 0.000000.
# TOPOSORT: Optimize destination fix previous solution with value 0.000000.
# Running TOPOSORT with (1) Alpha points=0.280000 (2) Duals from by
# TOPOSORT: Toposort found solution with value 0.000000.
# TOPOSORT: Optimize destination fix previous solution with value 0.000000.
# Running TOPOSORT with (1) Alpha points=0.300000 (2) Original obj.
# TOPOSORT: Toposort found solution with value 0.000000.
# TOPOSORT: Optimize destination fix previous solution with value 0.000000.
# Running TOPOSORT with (1) Alpha points=0.300000 (2) Discounted original obj.
# TOPOSORT: Toposort found solution with value 0.000000.
# TOPOSORT: Optimize destination fix previous solution with value 0.000000.
# Running TOPOSORT with (1) Alpha points=0.300000 (2) Duals from by
# TOPOSORT: Toposort found solution with value 0.000000.
# TOPOSORT: Optimize destination fix previous solution with value 0.000000.
# Running TOPOSORT with (1) Alpha points=0.320000 (2) Original obj.
# TOPOSORT: Toposort found solution with value 0.000000.
# TOPOSORT: Optimize destination fix previous solution with value 0.000000.
# Running TOPOSORT with (1) Alpha points=0.320000 (2) Discounted original obj.
# TOPOSORT: Toposort found solution with value 0.000000.
# TOPOSORT: Optimize destination fix previous solution with value 0.000000.
# Running TOPOSORT with (1) Alpha points=0.320000 (2) Duals from by
# TOPOSORT: Toposort found solution with value 0.000000.
# TOPOSORT: Optimize destination fix previous solution with value 0.000000.
# Running TOPOSORT with (1) Alpha points=0.340000 (2) Original obj.
# TOPOSORT: Toposort found solution with value 0.000000.
# TOPOSORT: Optimize destination fix previous solution with value 0.000000.
# Running TOPOSORT with (1) Alpha points=0.340000 (2) Discounted original obj.
# TOPOSORT: Toposort found solution with value 0.000000.
# TOPOSORT: Optimize destination fix previous solution with value 0.000000.
# Running TOPOSORT with (1) Alpha points=0.340000 (2) Duals from by
# TOPOSORT: Toposort found solution with value 0.000000.
# TOPOSORT: Optimize destination fix previous solution with value 0.000000.
# Running TOPOSORT with (1) Alpha points=0.360000 (2) Original obj.
# TOPOSORT: Toposort found solution with value 0.000000.
# TOPOSORT: Optimize destination fix previous solution with value 0.000000.
# Running TOPOSORT with (1) Alpha points=0.360000 (2) Discounted original obj.
# TOPOSORT: Toposort found solution with value 0.000000.
# TOPOSORT: Optimize destination fix previous solution with value 0.000000.
# Running TOPOSORT with (1) Alpha points=0.360000 (2) Duals from by
# TOPOSORT: Toposort found solution with value 0.000000.
# TOPOSORT: Optimize destination fix previous solution with value 0.000000.
# Running TOPOSORT with (1) Alpha points=0.380000 (2) Original obj.
# TOPOSORT: Toposort found solution with value 0.000000.
# TOPOSORT: Optimize destination fix previous solution with value 0.000000.
# Running TOPOSORT with (1) Alpha points=0.380000 (2) Discounted original obj.
# TOPOSORT: Toposort found solution with value 0.000000.
# TOPOSORT: Optimize destination fix previous solution with value 0.000000.
# Running TOPOSORT with (1) Alpha points=0.380000 (2) Duals from by
# TOPOSORT: Toposort found solution with value 0.000000.
# TOPOSORT: Optimize destination fix previous solution with value 0.000000.
# Running TOPOSORT with (1) Alpha points=0.400000 (2) Original obj.
# TOPOSORT: Toposort found solution with value 0.000000.
# TOPOSORT: Optimize destination fix previous solution with value 0.000000.
# Running TOPOSORT with (1) Alpha points=0.400000 (2) Discounted original obj.
# TOPOSORT: Toposort found solution with value 0.000000.
# TOPOSORT: Optimize destination fix previous solution with value 0.000000.
# Running TOPOSORT with (1) Alpha points=0.400000 (2) Duals from by
# TOPOSORT: Toposort found solution with value 0.000000.
# TOPOSORT: Optimize destination fix previous solution with value 0.000000.
# Running TOPOSORT with (1) Alpha points=0.420000 (2) Original obj.
# TOPOSORT: Toposort found solution with value 0.000000.
# TOPOSORT: Optimize destination fix previous solution with value 0.000000.
# Running TOPOSORT with (1) Alpha points=0.420000 (2) Discounted original obj.
# TOPOSORT: Toposort found solution with value 0.000000.
# TOPOSORT: Optimize destination fix previous solution with value 0.000000.
# Running TOPOSORT with (1) Alpha points=0.420000 (2) Duals from by
# TOPOSORT: Toposort found solution with value 0.000000.
# TOPOSORT: Optimize destination fix previous solution with value 0.000000.
# Running TOPOSORT with (1) Alpha points=0.440000 (2) Original obj.
# TOPOSORT: Toposort found solution with value 0.000000.
# TOPOSORT: Optimize destination fix previous solution with value 0.000000.
# Running TOPOSORT with (1) Alpha points=0.440000 (2) Discounted original obj.
# TOPOSORT: Toposort found solution with value 0.000000.
# TOPOSORT: Optimize destination fix previous solution with value 0.000000.
# Running TOPOSORT with (1) Alpha points=0.440000 (2) Duals from by
# TOPOSORT: Toposort found solution with value 0.000000.
# TOPOSORT: Optimize destination fix previous solution with value 0.000000.
# Running TOPOSORT with (1) Alpha points=0.460000 (2) Original obj.
# TOPOSORT: Toposort found solution with value 0.000000.
# TOPOSORT: Optimize destination fix previous solution with value 0.000000.
# Running TOPOSORT with (1) Alpha points=0.460000 (2) Discounted original obj.
# TOPOSORT: Toposort found solution with value 0.000000.
# TOPOSORT: Optimize destination fix previous solution with value 0.000000.
# Running TOPOSORT with (1) Alpha points=0.460000 (2) Duals from by
# TOPOSORT: Toposort found solution with value 0.000000.
# TOPOSORT: Optimize destination fix previous solution with value 0.000000.
# Running TOPOSORT with (1) Alpha points=0.480000 (2) Original obj.
# TOPOSORT: Toposort found solution with value 0.000000.
# TOPOSORT: Optimize destination fix previous solution with value 0.000000.
# Running TOPOSORT with (1) Alpha points=0.480000 (2) Discounted original obj.
# TOPOSORT: Toposort found solution with value 0.000000.
# TOPOSORT: Optimize destination fix previous solution with value 0.000000.
# Running TOPOSORT with (1) Alpha points=0.480000 (2) Duals from by
# TOPOSORT: Toposort found solution with value 0.000000.
# TOPOSORT: Optimize destination fix previous solution with value 0.000000.
# Running TOPOSORT with (1) Alpha points=0.500000 (2) Original obj.
# TOPOSORT: Toposort found solution with value 0.000000.
# TOPOSORT: Optimize destination fix previous solution with value 0.000000.
# Running TOPOSORT with (1) Alpha points=0.500000 (2) Discounted original obj.
# TOPOSORT: Toposort found solution with value 0.000000.
# TOPOSORT: Optimize destination fix previous solution with value 0.000000.
# Running TOPOSORT with (1) Alpha points=0.500000 (2) Duals from by
# TOPOSORT: Toposort found solution with value 0.000000.
# TOPOSORT: Optimize destination fix previous solution with value 0.000000.
# Running TOPOSORT with (1) Alpha points=0.520000 (2) Original obj.
# TOPOSORT: Toposort found solution with value 0.000000.
# TOPOSORT: Optimize destination fix previous solution with value 0.000000.
# Running TOPOSORT with (1) Alpha points=0.520000 (2) Discounted original obj.
# TOPOSORT: Toposort found solution with value 0.000000.
# TOPOSORT: Optimize destination fix previous solution with value 0.000000.
# Running TOPOSORT with (1) Alpha points=0.520000 (2) Duals from by
# TOPOSORT: Toposort found solution with value 0.000000.
# TOPOSORT: Optimize destination fix previous solution with value 0.000000.
# Running TOPOSORT with (1) Alpha points=0.540000 (2) Original obj.
# TOPOSORT: Toposort found solution with value 0.000000.
# TOPOSORT: Optimize destination fix previous solution with value 0.000000.
# Running TOPOSORT with (1) Alpha points=0.540000 (2) Discounted original obj.
# TOPOSORT: Toposort found solution with value 0.000000.
# TOPOSORT: Optimize destination fix previous solution with value 0.000000.
# Running TOPOSORT with (1) Alpha points=0.540000 (2) Duals from by
# TOPOSORT: Toposort found solution with value 0.000000.
# TOPOSORT: Optimize destination fix previous solution with value 0.000000.
# Running TOPOSORT with (1) Alpha points=0.560000 (2) Original obj.
# TOPOSORT: Toposort found solution with value 0.000000.
# TOPOSORT: Optimize destination fix previous solution with value 0.000000.
# Running TOPOSORT with (1) Alpha points=0.560000 (2) Discounted original obj.
# TOPOSORT: Toposort found solution with value 0.000000.
# TOPOSORT: Optimize destination fix previous solution with value 0.000000.
# Running TOPOSORT with (1) Alpha points=0.560000 (2) Duals from by
# TOPOSORT: Toposort found solution with value 0.000000.
# TOPOSORT: Optimize destination fix previous solution with value 0.000000.
# Running TOPOSORT with (1) Alpha points=0.580000 (2) Original obj.
# TOPOSORT: Toposort found solution with value 0.000000.
# TOPOSORT: Optimize destination fix previous solution with value 0.000000.
# Running TOPOSORT with (1) Alpha points=0.580000 (2) Discounted original obj.
# TOPOSORT: Toposort found solution with value 0.000000.
# TOPOSORT: Optimize destination fix previous solution with value 0.000000.
# Running TOPOSORT with (1) Alpha points=0.580000 (2) Duals from by
# TOPOSORT: Toposort found solution with value 0.000000.
# TOPOSORT: Optimize destination fix previous solution with value 0.000000.
# Running TOPOSORT with (1) Alpha points=0.600000 (2) Original obj.
# TOPOSORT: Toposort found solution with value 0.000000.
# TOPOSORT: Optimize destination fix previous solution with value 0.000000.
# Running TOPOSORT with (1) Alpha points=0.600000 (2) Discounted original obj.
# TOPOSORT: Toposort found solution with value 0.000000.
# TOPOSORT: Optimize destination fix previous solution with value 0.000000.
# Running TOPOSORT with (1) Alpha points=0.600000 (2) Duals from by
# TOPOSORT: Toposort found solution with value 0.000000.
# TOPOSORT: Optimize destination fix previous solution with value 0.000000.
# Running TOPOSORT with (1) Alpha points=0.620000 (2) Original obj.
# TOPOSORT: Toposort found solution with value 0.000000.
# TOPOSORT: Optimize destination fix previous solution with value 0.000000.
# Running TOPOSORT with (1) Alpha points=0.620000 (2) Discounted original obj.
# TOPOSORT: Toposort found solution with value 0.000000.
# TOPOSORT: Optimize destination fix previous solution with value 0.000000.
# Running TOPOSORT with (1) Alpha points=0.620000 (2) Duals from by
# TOPOSORT: Toposort found solution with value 0.000000.
# TOPOSORT: Optimize destination fix previous solution with value 0.000000.
# Running TOPOSORT with (1) Alpha points=0.640000 (2) Original obj.
# TOPOSORT: Toposort found solution with value 0.000000.
# TOPOSORT: Optimize destination fix previous solution with value 0.000000.
# Running TOPOSORT with (1) Alpha points=0.640000 (2) Discounted original obj.
# TOPOSORT: Toposort found solution with value 0.000000.
# TOPOSORT: Optimize destination fix previous solution with value 0.000000.
# Running TOPOSORT with (1) Alpha points=0.640000 (2) Duals from by
# TOPOSORT: Toposort found solution with value 0.000000.
# TOPOSORT: Optimize destination fix previous solution with value 0.000000.
# Running TOPOSORT with (1) Alpha points=0.660000 (2) Original obj.
# TOPOSORT: Toposort found solution with value 0.000000.
# TOPOSORT: Optimize destination fix previous solution with value 0.000000.
# Running TOPOSORT with (1) Alpha points=0.660000 (2) Discounted original obj.
# TOPOSORT: Toposort found solution with value 0.000000.
# TOPOSORT: Optimize destination fix previous solution with value 0.000000.
# Running TOPOSORT with (1) Alpha points=0.660000 (2) Duals from by
# TOPOSORT: Toposort found solution with value 0.000000.
# TOPOSORT: Optimize destination fix previous solution with value 0.000000.
# Running TOPOSORT with (1) Alpha points=0.680000 (2) Original obj.
# TOPOSORT: Toposort found solution with value 0.000000.
# TOPOSORT: Optimize destination fix previous solution with value 0.000000.
# Running TOPOSORT with (1) Alpha points=0.680000 (2) Discounted original obj.
# TOPOSORT: Toposort found solution with value 0.000000.
# TOPOSORT: Optimize destination fix previous solution with value 0.000000.
# Running TOPOSORT with (1) Alpha points=0.680000 (2) Duals from by
# TOPOSORT: Toposort found solution with value 0.000000.
# TOPOSORT: Optimize destination fix previous solution with value 0.000000.
# Running TOPOSORT with (1) Alpha points=0.700000 (2) Original obj.
# TOPOSORT: Toposort found solution with value 0.000000.
# TOPOSORT: Optimize destination fix previous solution with value 0.000000.
# Running TOPOSORT with (1) Alpha points=0.700000 (2) Discounted original obj.
# TOPOSORT: Toposort found solution with value 0.000000.
# TOPOSORT: Optimize destination fix previous solution with value 0.000000.
# Running TOPOSORT with (1) Alpha points=0.700000 (2) Duals from by
# TOPOSORT: Toposort found solution with value 0.000000.
# TOPOSORT: Optimize destination fix previous solution with value 0.000000.
# Running TOPOSORT with (1) Alpha points=0.720000 (2) Original obj.
# TOPOSORT: Toposort found solution with value 0.000000.
# TOPOSORT: Optimize destination fix previous solution with value 0.000000.
# Running TOPOSORT with (1) Alpha points=0.720000 (2) Discounted original obj.
# TOPOSORT: Toposort found solution with value 0.000000.
# TOPOSORT: Optimize destination fix previous solution with value 0.000000.
# Running TOPOSORT with (1) Alpha points=0.720000 (2) Duals from by
# TOPOSORT: Toposort found solution with value 0.000000.
# TOPOSORT: Optimize destination fix previous solution with value 0.000000.
# Running TOPOSORT with (1) Alpha points=0.740000 (2) Original obj.
# TOPOSORT: Toposort found solution with value 0.000000.
# TOPOSORT: Optimize destination fix previous solution with value 0.000000.
# Running TOPOSORT with (1) Alpha points=0.740000 (2) Discounted original obj.
# TOPOSORT: Toposort found solution with value 0.000000.
# TOPOSORT: Optimize destination fix previous solution with value 0.000000.
# Running TOPOSORT with (1) Alpha points=0.740000 (2) Duals from by
# TOPOSORT: Toposort found solution with value 0.000000.
# TOPOSORT: Optimize destination fix previous solution with value 0.000000.
# Running TOPOSORT with (1) Alpha points=0.760000 (2) Original obj.
# TOPOSORT: Toposort found solution with value 0.000000.
# TOPOSORT: Optimize destination fix previous solution with value 0.000000.
# Running TOPOSORT with (1) Alpha points=0.760000 (2) Discounted original obj.
# TOPOSORT: Toposort found solution with value 0.000000.
# TOPOSORT: Optimize destination fix previous solution with value 0.000000.
# Running TOPOSORT with (1) Alpha points=0.760000 (2) Duals from by
# TOPOSORT: Toposort found solution with value 0.000000.
# TOPOSORT: Optimize destination fix previous solution with value 0.000000.
# Running TOPOSORT with (1) Alpha points=0.780000 (2) Original obj.
# TOPOSORT: Toposort found solution with value 0.000000.
# TOPOSORT: Optimize destination fix previous solution with value 0.000000.
# Running TOPOSORT with (1) Alpha points=0.780000 (2) Discounted original obj.
# TOPOSORT: Toposort found solution with value 0.000000.
# TOPOSORT: Optimize destination fix previous solution with value 0.000000.
# Running TOPOSORT with (1) Alpha points=0.780000 (2) Duals from by
# TOPOSORT: Toposort found solution with value 0.000000.
# TOPOSORT: Optimize destination fix previous solution with value 0.000000.
# Running TOPOSORT with (1) Alpha points=0.800000 (2) Original obj.
# TOPOSORT: Toposort found solution with value 0.000000.
# TOPOSORT: Optimize destination fix previous solution with value 0.000000.
# Running TOPOSORT with (1) Alpha points=0.800000 (2) Discounted original obj.
# TOPOSORT: Toposort found solution with value 0.000000.
# TOPOSORT: Optimize destination fix previous solution with value 0.000000.
# Running TOPOSORT with (1) Alpha points=0.800000 (2) Duals from by
# TOPOSORT: Toposort found solution with value 0.000000.
# TOPOSORT: Optimize destination fix previous solution with value 0.000000.
# Running TOPOSORT with (1) Alpha points=0.820000 (2) Original obj.
# TOPOSORT: Toposort found solution with value 0.000000.
# TOPOSORT: Optimize destination fix previous solution with value 0.000000.
# Running TOPOSORT with (1) Alpha points=0.820000 (2) Discounted original obj.
# TOPOSORT: Toposort found solution with value 0.000000.
# TOPOSORT: Optimize destination fix previous solution with value 0.000000.
# Running TOPOSORT with (1) Alpha points=0.820000 (2) Duals from by
# TOPOSORT: Toposort found solution with value 0.000000.
# TOPOSORT: Optimize destination fix previous solution with value 0.000000.
# Running TOPOSORT with (1) Alpha points=0.840000 (2) Original obj.
# TOPOSORT: Toposort found solution with value 0.000000.
# TOPOSORT: Optimize destination fix previous solution with value 0.000000.
# Running TOPOSORT with (1) Alpha points=0.840000 (2) Discounted original obj.
# TOPOSORT: Toposort found solution with value 0.000000.
# TOPOSORT: Optimize destination fix previous solution with value 0.000000.
# Running TOPOSORT with (1) Alpha points=0.840000 (2) Duals from by
# TOPOSORT: Toposort found solution with value 0.000000.
# TOPOSORT: Optimize destination fix previous solution with value 0.000000.
# Running TOPOSORT with (1) Alpha points=0.860000 (2) Original obj.
# TOPOSORT: Toposort found solution with value 0.000000.
# TOPOSORT: Optimize destination fix previous solution with value 0.000000.
# Running TOPOSORT with (1) Alpha points=0.860000 (2) Discounted original obj.
# TOPOSORT: Toposort found solution with value 0.000000.
# TOPOSORT: Optimize destination fix previous solution with value 0.000000.
# Running TOPOSORT with (1) Alpha points=0.860000 (2) Duals from by
# TOPOSORT: Toposort found solution with value 0.000000.
# TOPOSORT: Optimize destination fix previous solution with value 0.000000.
# Running TOPOSORT with (1) Alpha points=0.880000 (2) Original obj.
# TOPOSORT: Toposort found solution with value 0.000000.
# TOPOSORT: Optimize destination fix previous solution with value 0.000000.
# Running TOPOSORT with (1) Alpha points=0.880000 (2) Discounted original obj.
# TOPOSORT: Toposort found solution with value 0.000000.
# TOPOSORT: Optimize destination fix previous solution with value 0.000000.
# Running TOPOSORT with (1) Alpha points=0.880000 (2) Duals from by
# TOPOSORT: Toposort found solution with value 0.000000.
# TOPOSORT: Optimize destination fix previous solution with value 0.000000.
# Running TOPOSORT with (1) Alpha points=0.900000 (2) Original obj.
# TOPOSORT: Toposort found solution with value 0.000000.
# TOPOSORT: Optimize destination fix previous solution with value 0.000000.
# Running TOPOSORT with (1) Alpha points=0.900000 (2) Discounted original obj.
# TOPOSORT: Toposort found solution with value 0.000000.
# TOPOSORT: Optimize destination fix previous solution with value 0.000000.
# Running TOPOSORT with (1) Alpha points=0.900000 (2) Duals from by
# TOPOSORT: Toposort found solution with value 0.000000.
# TOPOSORT: Optimize destination fix previous solution with value 0.000000.
# Running TOPOSORT with (1) Alpha points=0.920000 (2) Original obj.
# TOPOSORT: Toposort found solution with value 0.000000.
# TOPOSORT: Optimize destination fix previous solution with value 0.000000.
# Running TOPOSORT with (1) Alpha points=0.920000 (2) Discounted original obj.
# TOPOSORT: Toposort found solution with value 0.000000.
# TOPOSORT: Optimize destination fix previous solution with value 0.000000.
# Running TOPOSORT with (1) Alpha points=0.920000 (2) Duals from by
# TOPOSORT: Toposort found solution with value 0.000000.
# TOPOSORT: Optimize destination fix previous solution with value 0.000000.
# Running TOPOSORT with (1) Alpha points=0.940000 (2) Original obj.
# TOPOSORT: Toposort found solution with value 0.000000.
# TOPOSORT: Optimize destination fix previous solution with value 0.000000.
# Running TOPOSORT with (1) Alpha points=0.940000 (2) Discounted original obj.
# TOPOSORT: Toposort found solution with value 0.000000.
# TOPOSORT: Optimize destination fix previous solution with value 0.000000.
# Running TOPOSORT with (1) Alpha points=0.940000 (2) Duals from by
# TOPOSORT: Toposort found solution with value 0.000000.
# TOPOSORT: Optimize destination fix previous solution with value 0.000000.
# Running TOPOSORT with (1) Alpha points=0.960000 (2) Original obj.
# TOPOSORT: Toposort found solution with value 0.000000.
# TOPOSORT: Optimize destination fix previous solution with value 0.000000.
# Running TOPOSORT with (1) Alpha points=0.960000 (2) Discounted original obj.
# TOPOSORT: Toposort found solution with value 0.000000.
# TOPOSORT: Optimize destination fix previous solution with value 0.000000.
# Running TOPOSORT with (1) Alpha points=0.960000 (2) Duals from by
# TOPOSORT: Toposort found solution with value 0.000000.
# TOPOSORT: Optimize destination fix previous solution with value 0.000000.
# Running TOPOSORT with (1) Alpha points=0.980000 (2) Original obj.
# TOPOSORT: Toposort found solution with value 0.000000.
# TOPOSORT: Optimize destination fix previous solution with value 0.000000.
# Running TOPOSORT with (1) Alpha points=0.980000 (2) Discounted original obj.
# TOPOSORT: Toposort found solution with value 0.000000.
# TOPOSORT: Optimize destination fix previous solution with value 0.000000.
# Running TOPOSORT with (1) Alpha points=0.980000 (2) Duals from by
# TOPOSORT: Toposort found solution with value 0.000000.
# TOPOSORT: Optimize destination fix previous solution with value 0.000000.
# Running TOPOSORT with (1) Alpha points=1.000000 (2) Original obj.
# TOPOSORT: Toposort found solution with value 0.000000.
# TOPOSORT: Optimize destination fix previous solution with value 0.000000.
# Running TOPOSORT with (1) Alpha points=1.000000 (2) Discounted original obj.
# TOPOSORT: Toposort found solution with value 0.000000.
# TOPOSORT: Optimize destination fix previous solution with value 0.000000.
# Running TOPOSORT with (1) Alpha points=1.000000 (2) Duals from by
# TOPOSORT: Toposort found solution with value 0.000000.
# TOPOSORT: Optimize destination fix previous solution with value 0.000000.
# STATS_TOPOSORT_OBJVAL 0.000000
# STATS_TOPOSORT_TIME 0.017974
#
#
#           |------------------------------------------------------------|
#           |       TOPOSORT SOLUTION QUALITY INFORMATION                |
#           |------------------------------------------------------------|
#           |                                | PP-AGG Sol  |  Orig Sol   |
#           |--------------------------------+-------------+-------------|
#           | Const. violation (max 3.0e+05) |  3.0482e+08 |  3.0482e+08 |
#           | Prec violation   (max 1.0e-05) |  0.0000e+00 |  0.0000e+00 |
#           | Bounds violation (max 1.0e-05) | -0.0000e+00 | -0.0000e+00 |
#           | Is Feasible?                   |     No      |     No      |
#           |--------------------------------+-------------+-------------|
#           | W. Int. Viol.    (max 1.0e-02) |  0.0000e+00 |  0.0000e+00 |
#           | S. Int. Viol.    (max 1.0e-02) |  0.0000e+00 |  0.0000e+00 |
#           | Is Integer (weak)?             |     Yes     |     Yes     |
#           | Is Integer (strong)?           |     Yes     |     Yes     |
#           |--------------------------------+-------------+-------------|
#           | Objective Value                |  0.0000e+00 |  0.0000e+00 |
#           |--------------------------------+-------------+-------------|
#           | Best Previous LP Solution      |-1.7977e+308 |  6.6729e+08 |
#           | Replace Best LP Solution?      |     No      |     No      |
#           |------------------------------------------------------------|
#           | Best Previous IP Solution      |-1.7977e+308 |-1.7977e+308 |
#           | Replace Best IP Solution?      |     No      |     No      |
#           |--------------------------------+-------------+-------------|
#           | Best known Upper Bound         |             |-1.7977e+308 |
#           | Integrality Gap                |             |    -100.0%   |
#           |------------------------------------------------------------|
#
#           |------+------------------+---------+---------|
#           |  t   |    Objval[t]     | Perc[t] |  Acc[t] |
#           |------+------------------+---------+---------|
#           |------+------------------+---------+---------|
#           | tot  |           0.0000 | 100.00% | 100.00% |
#           |------+------------------+---------+---------|
#
#
# |-----+--------------------------------+--------------------------------+--------------------------------|
# |  t  |         CONSTRAINT:  0         |         CONSTRAINT:  1         |         CONSTRAINT:  2         |
# |-----+--------------------------------+--------------------------------+--------------------------------|
# |-----+--------------------------------+--------------------------------+--------------------------------|
#
#
#
# Done with Toposort in 0.023728 seconds. Time elapsed: 0.047868 in orsolver_internal (/home/nloira/projects/OMP/src/orsolver.c:1636)
#
# Done with Optimize Destination in 0.000000 seconds. Time elapsed: 0.047871 in orsolver_internal (/home/nloira/projects/OMP/src/orsolver.c:1718)
# Not performing naive heuristic
#
# Done with Naive in 0.000000 seconds. Time elapsed: 0.047873 in orsolver_internal (/home/nloira/projects/OMP/src/orsolver.c:1837)
#
# Done with CP in 0.000000 seconds. Time elapsed: 0.047875 in orsolver_internal (/home/nloira/projects/OMP/src/orsolver.c:1987)
# STATS_HEURISTICS_OBJVAL 0.000000
# STATS_HEURISTICS_TIME 0.023736
#
# Done with ORSOLVER in 0.047877 seconds. in orsolver_internal (/home/nloira/projects/OMP/src/orsolver.c:2241)
#
# HEADER: name param nbins_orig nblocks_orig ndest_orig nperiods_orig narcs_orig nbins_pp nblocks_pp ndestinations_pp nperiods_pp narcs_pp nconstraints nidx_at_orig nidx_at_pp nidx_by_pp time_input_testing time_preprocessing time_aggregation time_init_structs time_input_sol time_hotstart time_cuts time_LP time_topo time_naive time_rtw time_bb time_cp total_time cg_master_time cg_pricing_time cg_iterations bz_out_npartitions out_npartitions_bz out_nrounds_rootcp bb_niter lp_objval_orig lp_objval_pp lp_ubound ip_objval_orig ip_objval_pp ip_ubound toposort_objval naive_objval naive_od_objval rtw_objval
#
# SUMMARY: openPit_openPit_dbs_duals ../FilesToExecuteOmpOpenPit/params/dbs_duals.params 11760 11760 1 5 53312 848 848 1 5 3150 7 58800 3894 3894 0.000625 0.005351 0.000001 0.000582 0.000000 0.006549 0.000002 0.011009 0.023728 0.000000 0.000000 0.000000 0.000000 0.047877 0.002092 0.001860 3 44 0 0 0 667290078.347125 * * * * * 0.000000 * * *
#
#
# Finished OMP-ORSOLVER in 0.060090 seconds.
#
# STATS_TOTAL_TIME 0.060092

# %%
with open('fifthScenarioSolution', 'w') as f:
        f.write(str(openPitModel.execute()))
# Out:
# Running OMP version: master 1.8.5 d7d16093 2022-11-16 20:03:46 -0300
# Invoked using: bin/OMP_SOLVER_C1290 ../FilesToExecuteOmpOpenPit/files/openPit.blocks ../FilesToExecuteOmpOpenPit/files/openPit.prec ../FilesToExecuteOmpOpenPit/files/openPit.prob ../FilesToExecuteOmpOpenPit/params/dbs_duals.params
# license to sign [DEFAULTclient-signatureAFhG-4bsA-AAA=lic_ver200valid-to2023-03-07]
# LICENSE OK!
# BLOCKS FILE: ../FilesToExecuteOmpOpenPit/files/openPit.blocks
# PREC FILE: ../FilesToExecuteOmpOpenPit/files/openPit.prec
# PROB FILE: ../FilesToExecuteOmpOpenPit/files/openPit.prob
# PARAMS FILE: ../FilesToExecuteOmpOpenPit/params/dbs_duals.params
# OR Solver: key created. The key is: openPit_openPit_dbs_duals
# STATS_INPUT_NAME openPit_openPit_dbs_duals
# OR Solver: loaded params (params file) OK.
# STATS_PARAM_STOCHASTIC_MODE 0
# Objective: NPV
# DURATION loaded from column 2.
# Loaded prob file OK.
# Loaded block file columns OK.
# Vars and Prob populated OK.
# Block memory allocated OK.
# Block information in VARS populated OK.
# Bin information in VARS populated OK.
# dbldata OK.
# intdata OK.
# stockpiles OK.
# objfunction OK.
# objcols OK.
# Cleanup OK.
# OR Solver: loaded problem (prob and block files) OK.
# NNODES = 11760
# OR Solver: created arcs.
# STATS_INPUT_LOAD_TIME 0.009611
# EARLY START / TMIN PROPAGATION ELIMINATED 0 TIME PERIODS
# No bins eliminated due to propagation.
#
# ****************************
# ACTIVATED FEATURES:
# ****************************
# USE INPUT SOLUTION      : No
# USE PREPROCESSING       : Yes
# USE AGGREGATION         : No
# USE CUTTING PLANES      : No
# USE PRECOMPUTED COLUMNS : Yes
# SOLVE LP RELAXATION     : Yes
# USE HEURISTICS          : Yes
# USE BRANCH-AND-BOUND    : No
# ****************************
#
# ************************ INPUT DATA TESTING ************************
#
# RRCNT = 7
#
# INPUT DATA:
#
# nblocks=11760, nbins=11760, nperiods=5, ndestinations=1, nyvars=0, avg_nblockperiods=5.0, avg_nblockdestinations=1.0,  avg_nblocksinbin=1.0, narcs=53312,
# discount_rate=0.100000, rowcnt=7, sink_rate=0, phase_rate=0, max_open_benches=-1, nscenarios=0
# natvars (nidx) = 58800
# STATS_INPUT_NBLOCKS 11760
# STATS_INPUT_NBINS 11760
# STATS_INPUT_NPERIODS 5
# STATS_INPUT_SCENARIOS 0
# STATS_INPUT_NXVARS 58800
# STATS_INPUT_NYVARS 58800
# STATS_INPUT_NARCS 53312
# STATS_DISCOUNT_RATE 0.100000
#
# Done with input data testing in 0.000727 seconds. Time elapsed: 0.000732 in orsolver_internal (/home/nloira/projects/OMP/src/orsolver.c:277)
#
# ************************** PRE-PROCESSING **************************
#
# PP-ITERATION: 1
# ULTIMATE-PIT = Yes.
# UPIT value in Pre-Processing: 1487495320.073983, by elimimnating 10297 blocks. in ultimate_pit_pp (/home/nloira/projects/OMP/src/or_preprocess.c:179)
#     Problem qualifies for UPIT = Yes. in orsolver_internal (/home/nloira/projects/OMP/src/orsolver.c:484)
#     Number of bins eliminated = 10297. in orsolver_internal (/home/nloira/projects/OMP/src/orsolver.c:485)
# STATS_PPITER_UPIT_NBINS_REMOVED 10297
# STATS_PPITER_UPIT_NXVARS_REMOVED 51485
# WASTE-OPTION = Yes.
#     Number of block-destinations eliminated = 0. in orsolver_internal (/home/nloira/projects/OMP/src/orsolver.c:519)
# STATS_PPITER_MODEELIMINATION_NYVARS_REMOVED 0
# CAPACITY EARLY STARTS = Yes.
#     Number of bins eliminated = 85. in orsolver_internal (/home/nloira/projects/OMP/src/orsolver.c:576)
#     Number of additional bin-periods eliminated = 756. in orsolver_internal (/home/nloira/projects/OMP/src/orsolver.c:577)
# STATS_PPITER_EARLYSTARTS_NXVARS_REMOVED 1181
# STATS_PPITER_EARLYSTARTS_NYVARS_REMOVED 1181
# REMOVE NULL BINS = No .
# TRANSITIVE_REDUCTION = No .
# PP-ITERATION: 2
# ULTIMATE-PIT = Yes.
# UPIT value in Pre-Processing: 1188811301.309274, by elimimnating 530 blocks. in ultimate_pit_pp (/home/nloira/projects/OMP/src/or_preprocess.c:179)
#     Problem qualifies for UPIT = Yes. in orsolver_internal (/home/nloira/projects/OMP/src/orsolver.c:484)
#     Number of bins eliminated = 530. in orsolver_internal (/home/nloira/projects/OMP/src/orsolver.c:485)
# STATS_PPITER_UPIT_NBINS_REMOVED 530
# STATS_PPITER_UPIT_NXVARS_REMOVED 2240
# WASTE-OPTION = Yes.
#     Number of block-destinations eliminated = 0. in orsolver_internal (/home/nloira/projects/OMP/src/orsolver.c:519)
# STATS_PPITER_MODEELIMINATION_NYVARS_REMOVED 0
# CAPACITY EARLY STARTS = Yes.
#     Number of bins eliminated = 0. in orsolver_internal (/home/nloira/projects/OMP/src/orsolver.c:576)
#     Number of additional bin-periods eliminated = 0. in orsolver_internal (/home/nloira/projects/OMP/src/orsolver.c:577)
# STATS_PPITER_EARLYSTARTS_NXVARS_REMOVED 0
# STATS_PPITER_EARLYSTARTS_NYVARS_REMOVED 0
# REMOVE NULL BINS = No .
# TRANSITIVE_REDUCTION = No .
# PP-ITERATION: 3
# ULTIMATE-PIT = Yes.
# UPIT value in Pre-Processing: 1188811301.309274, by elimimnating 0 blocks. in ultimate_pit_pp (/home/nloira/projects/OMP/src/or_preprocess.c:179)
#     Problem qualifies for UPIT = Yes. in orsolver_internal (/home/nloira/projects/OMP/src/orsolver.c:484)
#     Number of bins eliminated = 0. in orsolver_internal (/home/nloira/projects/OMP/src/orsolver.c:485)
# STATS_PPITER_UPIT_NBINS_REMOVED 0
# STATS_PPITER_UPIT_NXVARS_REMOVED 0
# WASTE-OPTION = Yes.
#     Number of block-destinations eliminated = 0. in orsolver_internal (/home/nloira/projects/OMP/src/orsolver.c:519)
# STATS_PPITER_MODEELIMINATION_NYVARS_REMOVED 0
# CAPACITY EARLY STARTS = Yes.
#     Number of bins eliminated = 0. in orsolver_internal (/home/nloira/projects/OMP/src/orsolver.c:576)
#     Number of additional bin-periods eliminated = 0. in orsolver_internal (/home/nloira/projects/OMP/src/orsolver.c:577)
# STATS_PPITER_EARLYSTARTS_NXVARS_REMOVED 0
# STATS_PPITER_EARLYSTARTS_NYVARS_REMOVED 0
# REMOVE NULL BINS = No .
# TRANSITIVE_REDUCTION = No .
# STATS_PP_NITERATIONS 3
# STATS_PP_UPIT_NBINS_REMOVED 10827
# STATS_PP_UPIT_NXVARS_REMOVED 53725
# STATS_PP_EARLYSTARTS_NXVARS_REMOVED 1181
# STATS_PP_EARLYSTARTS_NYVARS_REMOVED 1181
# STATS_PP_MODEELIMINATION_NYVARS_REMOVED 0
# STATS_PP_NULLBINS_NXVARS_REMOVED 0
# STATS_PP_NULLBINS_NYVARS_REMOVED 0
# STATS_PP_NULLBINS_NARCS_ADDED 0
# STATS_PP_TRANSITIVEREDUCTION_NARCS_REMOVED 0
# STATS_PP_NXVARS_REMOVED 54906
# STATS_PP_NYVARS_REMOVED 54906
# STATS_PP_NARCS_REMOVED 50162
# STATS_PP_TIME 0.004204
#
# Done with preprocessing in 0.005590 seconds Time elapsed: 0.006324 in orsolver_internal (/home/nloira/projects/OMP/src/orsolver.c:705)
#
# *************************** AGGREGATION ****************************
#
# BLOCK_AGGREGATION = No .
#
# Done with aggregation in 0.000001 seconds. Time elapsed: 0.006326 in orsolver_internal (/home/nloira/projects/OMP/src/orsolver.c:750)
#
# ******************* INITIALIZING DATA STRUCTURES *******************
#
# RRCNT = 7
# BY-LP problem created. It has 3894 variables, 17066 precedence constraints, 35 resource constraints and 35560 non-zero coefficients in the resource constraints. in orsolver_internal (/home/nloira/projects/OMP/src/orsolver.c:867)
#
# PREPROCESSED AND AGGREGATED DATA:
#
# nblocks=848, nbins=848, nperiods=5, ndestinations=1, nyvars=0, avg_nblockperiods=4.6, avg_nblockdestinations=1.0,  avg_nblocksinbin=1.0, narcs=3150,
# discount_rate=0.100000, rowcnt=7, sink_rate=0, phase_rate=0, max_open_benches=-1, nscenarios=0
# natvars (nidx) = 3894
#
# Done with input data testing in 0.000566 seconds. Time elapsed: 0.006893 in orsolver_internal (/home/nloira/projects/OMP/src/orsolver.c:891)
#
# ********************* ANALYZING INPUT SOLUTION *********************
#
# There is no input solution
#
# Done with input solution analysis in 0.000000 seconds. Time elapsed: 0.006895 in orsolver_internal (/home/nloira/projects/OMP/src/orsolver.c:1020)
#
# *********************** PRECOMPUTING COLUMNS ***********************
#
# CPIT starting-solution: Yes
# CPIT computed for constraint 0 obtaining a value of 692689920.719881
# Creating initial partition of size 7
# CPIT computed for constraint 1 obtaining a value of 289494149.192713
# Refinining initial partition, new size is 13
# CPIT computed for constraint 2 obtaining a value of 250494143.846992
# Refinining initial partition, new size is 16
# CPIT computed for constraint 3 obtaining a value of 0.000000
# Refinining initial partition, new size is 16
# CPIT computed for constraint 4 obtaining a value of 1188811301.309274
# Refinining initial partition, new size is 16
# CPIT computed for constraint 5 obtaining a value of 1171016435.333335
# Refinining initial partition, new size is 18
# CPIT computed for constraint 6 obtaining a value of 0.000000
# Refinining initial partition, new size is 18
# Starting with partition defined by CPIT.
#
# Done with hot start columns in 0.006691 seconds. Time elapsed: 0.013587 in orsolver_internal (/home/nloira/projects/OMP/src/orsolver.c:1093)
#
# ************************ PRECOMPUTING CUTS *************************
#
# Not using cuts
#
# Done with cuts in 0.000002 seconds. Time elapsed: 0.013591 in orsolver_internal (/home/nloira/projects/OMP/src/orsolver.c:1213)
#
# ***************************** LP-SOLVE *****************************
#
# OPTIMIZATION method: Bienstock-Zuckerberg.
#
# |-----+-----------+---------------------+--------------------+-----------+-----------+-----------+-----------+-----------+------------|
# | BIENSTOCK-ZUCKERBERG ALGORITHM: Target gap = 1.00e-04.  Target eps = 1.00e-06.  Starting phase = Phase  I.                          |
# | Number of variables: tot = 3929, x = 3894, y = 0, s = 35, Use step = 0 (10), kstep = 0, lstep = 0, xstep = 0 (-1)
# |-----+-----------+---------------------+--------------------+-----------+-----------+-----------+-----------+-----------+------------|
# |Iter.|#Part.     |    Primal Value     |  Lagrangian Value  |    Gap    | Pri. Time | Mas. Time | Tot. Time | Pri. Eps. |   Kappa    |
# |-----+-----------+---------------------+--------------------+-----------+-----------+-----------+-----------+-----------+------------|
# |   1 |   19   80 |            Phase  I |      1.0516447e+09 |  1.00e+00 |  0.000605 |   0.00114 |   0.00186 |  3.05e+08 |     32.619 |
# |   2 |   29  125 |            Phase IB |      1.1642371e+17 |  1.87e+04 |   0.00134 |   0.00158 |   0.00307 |  3.05e+08 |     31.741 |
# |   3 |   44  194 |            Phase IB |     -6.2404801e+12 |  2.58e-05 |   0.00221 |   0.00257 |   0.00494 |  3.05e+08 |     120.05 |
# |-----+-----------+---------------------+--------------------+-----------+-----------+-----------+-----------+-----------+------------|
# *   3 |   44  194 | Phase IB |    -1.7976931e+308 |  2.58e-05 |   0.00221 |   0.00257 |   0.00494 |     3e+08 |     120.05 | OMP_INFEASIBLE
# |-----+-----------+---------------------+--------------------+-----------+-----------+-----------+-----------+-----------+------------|
#
# PRINTING BZ DUAL INFORMATION
#
# BZ_DUAL: row= 0  pi= 23.418977  sense= L  rhs= 13219200.000000
# BZ_DUAL: row= 1  pi= 25.341654  sense= L  rhs= 13219200.000000
# BZ_DUAL: row= 2  pi= 25.357862  sense= L  rhs= 13219200.000000
# BZ_DUAL: row= 3  pi= 25.357862  sense= L  rhs= 13219200.000000
# BZ_DUAL: row= 4  pi= 25.357862  sense= L  rhs= 13219200.000000
# BZ_DUAL: row= 10  pi= 2.027477  sense= L  rhs= 10933380.000000
# BZ_DUAL: row= 34  pi= 4096.000000  sense= L  rhs= 0.000000
#
#
# STATS_BZ_NITERATIONS 3
# STATS_BZ_SOLVETIME 0.005411
# STATS_BZ_PRICINGTIME 0.002215
# STATS_BZ_MASTERTIME 0.002566
# STATS_BZ_NPARTITIONS 44
# STATS_NCUTS 0
# STATS_NCUT_ROUNDS 0
#
#
#           |------------------------------------------------------------|
#           |       BZ SOLUTION QUALITY INFORMATION                      |
#           |------------------------------------------------------------|
#           |                                | PP-AGG Sol  |  Orig Sol   |
#           |--------------------------------+-------------+-------------|
#           | Const. violation (max 3.0e+05) |  3.0473e+08 |  3.0473e+08 |
#           | Prec violation   (max 1.0e-05) |  0.0000e+00 |  0.0000e+00 |
#           | Bounds violation (max 1.0e-05) |  0.0000e+00 |  0.0000e+00 |
#           | Is Feasible?                   |     No      |     No      |
#           |--------------------------------+-------------+-------------|
#           | W. Int. Viol.    (max 1.0e-02) |  4.4288e-01 |  4.4288e-01 |
#           | S. Int. Viol.    (max 1.0e-02) |  4.9490e-01 |  4.9490e-01 |
#           | Is Integer (weak)?             |     No      |     No      |
#           | Is Integer (strong)?           |     No      |     No      |
#           |--------------------------------+-------------+-------------|
#           | Objective Value                |  6.6729e+08 |  6.6729e+08 |
#           |--------------------------------+-------------+-------------|
#           | Best Previous LP Solution      |-1.7977e+308 |-1.7977e+308 |
#           | Replace Best LP Solution?      |     No      |     Yes     |
#           |------------------------------------------------------------|
#           | Best Previous IP Solution      |-1.7977e+308 |-1.7977e+308 |
#           | Replace Best IP Solution?      |     No      |     No      |
#           |------------------------------------------------------------|
#             BZ SOLUTION written to openPit_openPit_dbs_duals.BZ.lp.sol
#
#           |------+------------------+---------+---------|
#           |  t   |    Objval[t]     | Perc[t] |  Acc[t] |
#           |------+------------------+---------+---------|
#           |    0 |   132650185.8764 |  19.88% |  19.88% |
#           |    1 |   117117946.6034 |  17.55% |  37.43% |
#           |    2 |   211516503.1427 |  31.70% |  69.13% |
#           |    3 |   107380738.5055 |  16.09% |  85.22% |
#           |    4 |    98624704.2191 |  14.78% | 100.00% |
#           |------+------------------+---------+---------|
#           | tot  |   667290078.3471 | 100.00% | 100.00% |
#           |------+------------------+---------+---------|
#
#
# |-----+--------------------------------+--------------------------------+--------------------------------|
# |  t  |         CONSTRAINT:  0         |         CONSTRAINT:  1         |         CONSTRAINT:  2         |
# |-----+--------------------------------+--------------------------------+--------------------------------|
# |   0 |   13219200.00 <=   13219200.00 |   13219200.00 >=    8812800.00 |   10933380.00 <=   10933380.00 |
# |   1 |   13219200.00 <=   13219200.00 |   13219200.00 >=    8812800.00 |   10599400.34 <=   10933380.00 |
# |   2 |   13219200.00 <=   13219200.00 |   13219200.00 >=    8812800.00 |   10933380.00 <=   10933380.00 |
# |   3 |   13219200.00 <=   13219200.00 |   13219200.00 >=    8812800.00 |    9022768.43 <=   10933380.00 |
# |   4 |   13219200.00 <=   13219200.00 |   13219200.00 >=    8812800.00 |    7428902.41 <=   10933380.00 |
# |-----+--------------------------------+--------------------------------+--------------------------------|
#
#
#
# Done with solving LP relaxation in 0.011384 seconds. Time elapsed: 0.024977 in orsolver_internal (/home/nloira/projects/OMP/src/orsolver.c:1553)
#
# ***************************** TOPOSORT *****************************
#
# TOPOSORT: Problem has all knapsack constraints. Proceeding with toposort algorithms.
# TOPOSORT: Use binary toposort = Yes.
# TOPOSORT: Use fractional toposort = No .
# TOPOSORT: Use mixed toposort = No .
# TOPOSORT: Use alpha-points toposort = Yes (nalpha_points=50).
# TOPOSORT: Use opt-destination = Yes.
# TOPOSORT: WARNING! Constraint 1 is not a knapsack constraint, so the solution of Toposort can be infeasible
# TOPOSORT: WARNING! Constraint 3 is not a knapsack constraint, so the solution of Toposort can be infeasible
# TOPOSORT: WARNING! Constraint 5 is not a knapsack constraint, so the solution of Toposort can be infeasible
# Running TOPOSORT with (1) Expected Time (2) Original obj.
# TOPOSORT: Toposort found solution with value 0.000000.
# TOPOSORT: Optimize destination fix previous solution with value 0.000000.
# Running TOPOSORT with (1) Expected Time (2) Discounted original obj.
# TOPOSORT: Toposort found solution with value 0.000000.
# TOPOSORT: Optimize destination fix previous solution with value 0.000000.
# Running TOPOSORT with (1) Expected Time (2) Duals from by
# TOPOSORT: Toposort found solution with value 0.000000.
# TOPOSORT: Optimize destination fix previous solution with value 0.000000.
# Running TOPOSORT with (1) Alpha points=0.020000 (2) Original obj.
# TOPOSORT: Toposort found solution with value 0.000000.
# TOPOSORT: Optimize destination fix previous solution with value 0.000000.
# Running TOPOSORT with (1) Alpha points=0.020000 (2) Discounted original obj.
# TOPOSORT: Toposort found solution with value 0.000000.
# TOPOSORT: Optimize destination fix previous solution with value 0.000000.
# Running TOPOSORT with (1) Alpha points=0.020000 (2) Duals from by
# TOPOSORT: Toposort found solution with value 0.000000.
# TOPOSORT: Optimize destination fix previous solution with value 0.000000.
# Running TOPOSORT with (1) Alpha points=0.040000 (2) Original obj.
# TOPOSORT: Toposort found solution with value 0.000000.
# TOPOSORT: Optimize destination fix previous solution with value 0.000000.
# Running TOPOSORT with (1) Alpha points=0.040000 (2) Discounted original obj.
# TOPOSORT: Toposort found solution with value 0.000000.
# TOPOSORT: Optimize destination fix previous solution with value 0.000000.
# Running TOPOSORT with (1) Alpha points=0.040000 (2) Duals from by
# TOPOSORT: Toposort found solution with value 0.000000.
# TOPOSORT: Optimize destination fix previous solution with value 0.000000.
# Running TOPOSORT with (1) Alpha points=0.060000 (2) Original obj.
# TOPOSORT: Toposort found solution with value 0.000000.
# TOPOSORT: Optimize destination fix previous solution with value 0.000000.
# Running TOPOSORT with (1) Alpha points=0.060000 (2) Discounted original obj.
# TOPOSORT: Toposort found solution with value 0.000000.
# TOPOSORT: Optimize destination fix previous solution with value 0.000000.
# Running TOPOSORT with (1) Alpha points=0.060000 (2) Duals from by
# TOPOSORT: Toposort found solution with value 0.000000.
# TOPOSORT: Optimize destination fix previous solution with value 0.000000.
# Running TOPOSORT with (1) Alpha points=0.080000 (2) Original obj.
# TOPOSORT: Toposort found solution with value 0.000000.
# TOPOSORT: Optimize destination fix previous solution with value 0.000000.
# Running TOPOSORT with (1) Alpha points=0.080000 (2) Discounted original obj.
# TOPOSORT: Toposort found solution with value 0.000000.
# TOPOSORT: Optimize destination fix previous solution with value 0.000000.
# Running TOPOSORT with (1) Alpha points=0.080000 (2) Duals from by
# TOPOSORT: Toposort found solution with value 0.000000.
# TOPOSORT: Optimize destination fix previous solution with value 0.000000.
# Running TOPOSORT with (1) Alpha points=0.100000 (2) Original obj.
# TOPOSORT: Toposort found solution with value 0.000000.
# TOPOSORT: Optimize destination fix previous solution with value 0.000000.
# Running TOPOSORT with (1) Alpha points=0.100000 (2) Discounted original obj.
# TOPOSORT: Toposort found solution with value 0.000000.
# TOPOSORT: Optimize destination fix previous solution with value 0.000000.
# Running TOPOSORT with (1) Alpha points=0.100000 (2) Duals from by
# TOPOSORT: Toposort found solution with value 0.000000.
# TOPOSORT: Optimize destination fix previous solution with value 0.000000.
# Running TOPOSORT with (1) Alpha points=0.120000 (2) Original obj.
# TOPOSORT: Toposort found solution with value 0.000000.
# TOPOSORT: Optimize destination fix previous solution with value 0.000000.
# Running TOPOSORT with (1) Alpha points=0.120000 (2) Discounted original obj.
# TOPOSORT: Toposort found solution with value 0.000000.
# TOPOSORT: Optimize destination fix previous solution with value 0.000000.
# Running TOPOSORT with (1) Alpha points=0.120000 (2) Duals from by
# TOPOSORT: Toposort found solution with value 0.000000.
# TOPOSORT: Optimize destination fix previous solution with value 0.000000.
# Running TOPOSORT with (1) Alpha points=0.140000 (2) Original obj.
# TOPOSORT: Toposort found solution with value 0.000000.
# TOPOSORT: Optimize destination fix previous solution with value 0.000000.
# Running TOPOSORT with (1) Alpha points=0.140000 (2) Discounted original obj.
# TOPOSORT: Toposort found solution with value 0.000000.
# TOPOSORT: Optimize destination fix previous solution with value 0.000000.
# Running TOPOSORT with (1) Alpha points=0.140000 (2) Duals from by
# TOPOSORT: Toposort found solution with value 0.000000.
# TOPOSORT: Optimize destination fix previous solution with value 0.000000.
# Running TOPOSORT with (1) Alpha points=0.160000 (2) Original obj.
# TOPOSORT: Toposort found solution with value 0.000000.
# TOPOSORT: Optimize destination fix previous solution with value 0.000000.
# Running TOPOSORT with (1) Alpha points=0.160000 (2) Discounted original obj.
# TOPOSORT: Toposort found solution with value 0.000000.
# TOPOSORT: Optimize destination fix previous solution with value 0.000000.
# Running TOPOSORT with (1) Alpha points=0.160000 (2) Duals from by
# TOPOSORT: Toposort found solution with value 0.000000.
# TOPOSORT: Optimize destination fix previous solution with value 0.000000.
# Running TOPOSORT with (1) Alpha points=0.180000 (2) Original obj.
# TOPOSORT: Toposort found solution with value 0.000000.
# TOPOSORT: Optimize destination fix previous solution with value 0.000000.
# Running TOPOSORT with (1) Alpha points=0.180000 (2) Discounted original obj.
# TOPOSORT: Toposort found solution with value 0.000000.
# TOPOSORT: Optimize destination fix previous solution with value 0.000000.
# Running TOPOSORT with (1) Alpha points=0.180000 (2) Duals from by
# TOPOSORT: Toposort found solution with value 0.000000.
# TOPOSORT: Optimize destination fix previous solution with value 0.000000.
# Running TOPOSORT with (1) Alpha points=0.200000 (2) Original obj.
# TOPOSORT: Toposort found solution with value 0.000000.
# TOPOSORT: Optimize destination fix previous solution with value 0.000000.
# Running TOPOSORT with (1) Alpha points=0.200000 (2) Discounted original obj.
# TOPOSORT: Toposort found solution with value 0.000000.
# TOPOSORT: Optimize destination fix previous solution with value 0.000000.
# Running TOPOSORT with (1) Alpha points=0.200000 (2) Duals from by
# TOPOSORT: Toposort found solution with value 0.000000.
# TOPOSORT: Optimize destination fix previous solution with value 0.000000.
# Running TOPOSORT with (1) Alpha points=0.220000 (2) Original obj.
# TOPOSORT: Toposort found solution with value 0.000000.
# TOPOSORT: Optimize destination fix previous solution with value 0.000000.
# Running TOPOSORT with (1) Alpha points=0.220000 (2) Discounted original obj.
# TOPOSORT: Toposort found solution with value 0.000000.
# TOPOSORT: Optimize destination fix previous solution with value 0.000000.
# Running TOPOSORT with (1) Alpha points=0.220000 (2) Duals from by
# TOPOSORT: Toposort found solution with value 0.000000.
# TOPOSORT: Optimize destination fix previous solution with value 0.000000.
# Running TOPOSORT with (1) Alpha points=0.240000 (2) Original obj.
# TOPOSORT: Toposort found solution with value 0.000000.
# TOPOSORT: Optimize destination fix previous solution with value 0.000000.
# Running TOPOSORT with (1) Alpha points=0.240000 (2) Discounted original obj.
# TOPOSORT: Toposort found solution with value 0.000000.
# TOPOSORT: Optimize destination fix previous solution with value 0.000000.
# Running TOPOSORT with (1) Alpha points=0.240000 (2) Duals from by
# TOPOSORT: Toposort found solution with value 0.000000.
# TOPOSORT: Optimize destination fix previous solution with value 0.000000.
# Running TOPOSORT with (1) Alpha points=0.260000 (2) Original obj.
# TOPOSORT: Toposort found solution with value 0.000000.
# TOPOSORT: Optimize destination fix previous solution with value 0.000000.
# Running TOPOSORT with (1) Alpha points=0.260000 (2) Discounted original obj.
# TOPOSORT: Toposort found solution with value 0.000000.
# TOPOSORT: Optimize destination fix previous solution with value 0.000000.
# Running TOPOSORT with (1) Alpha points=0.260000 (2) Duals from by
# TOPOSORT: Toposort found solution with value 0.000000.
# TOPOSORT: Optimize destination fix previous solution with value 0.000000.
# Running TOPOSORT with (1) Alpha points=0.280000 (2) Original obj.
# TOPOSORT: Toposort found solution with value 0.000000.
# TOPOSORT: Optimize destination fix previous solution with value 0.000000.
# Running TOPOSORT with (1) Alpha points=0.280000 (2) Discounted original obj.
# TOPOSORT: Toposort found solution with value 0.000000.
# TOPOSORT: Optimize destination fix previous solution with value 0.000000.
# Running TOPOSORT with (1) Alpha points=0.280000 (2) Duals from by
# TOPOSORT: Toposort found solution with value 0.000000.
# TOPOSORT: Optimize destination fix previous solution with value 0.000000.
# Running TOPOSORT with (1) Alpha points=0.300000 (2) Original obj.
# TOPOSORT: Toposort found solution with value 0.000000.
# TOPOSORT: Optimize destination fix previous solution with value 0.000000.
# Running TOPOSORT with (1) Alpha points=0.300000 (2) Discounted original obj.
# TOPOSORT: Toposort found solution with value 0.000000.
# TOPOSORT: Optimize destination fix previous solution with value 0.000000.
# Running TOPOSORT with (1) Alpha points=0.300000 (2) Duals from by
# TOPOSORT: Toposort found solution with value 0.000000.
# TOPOSORT: Optimize destination fix previous solution with value 0.000000.
# Running TOPOSORT with (1) Alpha points=0.320000 (2) Original obj.
# TOPOSORT: Toposort found solution with value 0.000000.
# TOPOSORT: Optimize destination fix previous solution with value 0.000000.
# Running TOPOSORT with (1) Alpha points=0.320000 (2) Discounted original obj.
# TOPOSORT: Toposort found solution with value 0.000000.
# TOPOSORT: Optimize destination fix previous solution with value 0.000000.
# Running TOPOSORT with (1) Alpha points=0.320000 (2) Duals from by
# TOPOSORT: Toposort found solution with value 0.000000.
# TOPOSORT: Optimize destination fix previous solution with value 0.000000.
# Running TOPOSORT with (1) Alpha points=0.340000 (2) Original obj.
# TOPOSORT: Toposort found solution with value 0.000000.
# TOPOSORT: Optimize destination fix previous solution with value 0.000000.
# Running TOPOSORT with (1) Alpha points=0.340000 (2) Discounted original obj.
# TOPOSORT: Toposort found solution with value 0.000000.
# TOPOSORT: Optimize destination fix previous solution with value 0.000000.
# Running TOPOSORT with (1) Alpha points=0.340000 (2) Duals from by
# TOPOSORT: Toposort found solution with value 0.000000.
# TOPOSORT: Optimize destination fix previous solution with value 0.000000.
# Running TOPOSORT with (1) Alpha points=0.360000 (2) Original obj.
# TOPOSORT: Toposort found solution with value 0.000000.
# TOPOSORT: Optimize destination fix previous solution with value 0.000000.
# Running TOPOSORT with (1) Alpha points=0.360000 (2) Discounted original obj.
# TOPOSORT: Toposort found solution with value 0.000000.
# TOPOSORT: Optimize destination fix previous solution with value 0.000000.
# Running TOPOSORT with (1) Alpha points=0.360000 (2) Duals from by
# TOPOSORT: Toposort found solution with value 0.000000.
# TOPOSORT: Optimize destination fix previous solution with value 0.000000.
# Running TOPOSORT with (1) Alpha points=0.380000 (2) Original obj.
# TOPOSORT: Toposort found solution with value 0.000000.
# TOPOSORT: Optimize destination fix previous solution with value 0.000000.
# Running TOPOSORT with (1) Alpha points=0.380000 (2) Discounted original obj.
# TOPOSORT: Toposort found solution with value 0.000000.
# TOPOSORT: Optimize destination fix previous solution with value 0.000000.
# Running TOPOSORT with (1) Alpha points=0.380000 (2) Duals from by
# TOPOSORT: Toposort found solution with value 0.000000.
# TOPOSORT: Optimize destination fix previous solution with value 0.000000.
# Running TOPOSORT with (1) Alpha points=0.400000 (2) Original obj.
# TOPOSORT: Toposort found solution with value 0.000000.
# TOPOSORT: Optimize destination fix previous solution with value 0.000000.
# Running TOPOSORT with (1) Alpha points=0.400000 (2) Discounted original obj.
# TOPOSORT: Toposort found solution with value 0.000000.
# TOPOSORT: Optimize destination fix previous solution with value 0.000000.
# Running TOPOSORT with (1) Alpha points=0.400000 (2) Duals from by
# TOPOSORT: Toposort found solution with value 0.000000.
# TOPOSORT: Optimize destination fix previous solution with value 0.000000.
# Running TOPOSORT with (1) Alpha points=0.420000 (2) Original obj.
# TOPOSORT: Toposort found solution with value 0.000000.
# TOPOSORT: Optimize destination fix previous solution with value 0.000000.
# Running TOPOSORT with (1) Alpha points=0.420000 (2) Discounted original obj.
# TOPOSORT: Toposort found solution with value 0.000000.
# TOPOSORT: Optimize destination fix previous solution with value 0.000000.
# Running TOPOSORT with (1) Alpha points=0.420000 (2) Duals from by
# TOPOSORT: Toposort found solution with value 0.000000.
# TOPOSORT: Optimize destination fix previous solution with value 0.000000.
# Running TOPOSORT with (1) Alpha points=0.440000 (2) Original obj.
# TOPOSORT: Toposort found solution with value 0.000000.
# TOPOSORT: Optimize destination fix previous solution with value 0.000000.
# Running TOPOSORT with (1) Alpha points=0.440000 (2) Discounted original obj.
# TOPOSORT: Toposort found solution with value 0.000000.
# TOPOSORT: Optimize destination fix previous solution with value 0.000000.
# Running TOPOSORT with (1) Alpha points=0.440000 (2) Duals from by
# TOPOSORT: Toposort found solution with value 0.000000.
# TOPOSORT: Optimize destination fix previous solution with value 0.000000.
# Running TOPOSORT with (1) Alpha points=0.460000 (2) Original obj.
# TOPOSORT: Toposort found solution with value 0.000000.
# TOPOSORT: Optimize destination fix previous solution with value 0.000000.
# Running TOPOSORT with (1) Alpha points=0.460000 (2) Discounted original obj.
# TOPOSORT: Toposort found solution with value 0.000000.
# TOPOSORT: Optimize destination fix previous solution with value 0.000000.
# Running TOPOSORT with (1) Alpha points=0.460000 (2) Duals from by
# TOPOSORT: Toposort found solution with value 0.000000.
# TOPOSORT: Optimize destination fix previous solution with value 0.000000.
# Running TOPOSORT with (1) Alpha points=0.480000 (2) Original obj.
# TOPOSORT: Toposort found solution with value 0.000000.
# TOPOSORT: Optimize destination fix previous solution with value 0.000000.
# Running TOPOSORT with (1) Alpha points=0.480000 (2) Discounted original obj.
# TOPOSORT: Toposort found solution with value 0.000000.
# TOPOSORT: Optimize destination fix previous solution with value 0.000000.
# Running TOPOSORT with (1) Alpha points=0.480000 (2) Duals from by
# TOPOSORT: Toposort found solution with value 0.000000.
# TOPOSORT: Optimize destination fix previous solution with value 0.000000.
# Running TOPOSORT with (1) Alpha points=0.500000 (2) Original obj.
# TOPOSORT: Toposort found solution with value 0.000000.
# TOPOSORT: Optimize destination fix previous solution with value 0.000000.
# Running TOPOSORT with (1) Alpha points=0.500000 (2) Discounted original obj.
# TOPOSORT: Toposort found solution with value 0.000000.
# TOPOSORT: Optimize destination fix previous solution with value 0.000000.
# Running TOPOSORT with (1) Alpha points=0.500000 (2) Duals from by
# TOPOSORT: Toposort found solution with value 0.000000.
# TOPOSORT: Optimize destination fix previous solution with value 0.000000.
# Running TOPOSORT with (1) Alpha points=0.520000 (2) Original obj.
# TOPOSORT: Toposort found solution with value 0.000000.
# TOPOSORT: Optimize destination fix previous solution with value 0.000000.
# Running TOPOSORT with (1) Alpha points=0.520000 (2) Discounted original obj.
# TOPOSORT: Toposort found solution with value 0.000000.
# TOPOSORT: Optimize destination fix previous solution with value 0.000000.
# Running TOPOSORT with (1) Alpha points=0.520000 (2) Duals from by
# TOPOSORT: Toposort found solution with value 0.000000.
# TOPOSORT: Optimize destination fix previous solution with value 0.000000.
# Running TOPOSORT with (1) Alpha points=0.540000 (2) Original obj.
# TOPOSORT: Toposort found solution with value 0.000000.
# TOPOSORT: Optimize destination fix previous solution with value 0.000000.
# Running TOPOSORT with (1) Alpha points=0.540000 (2) Discounted original obj.
# TOPOSORT: Toposort found solution with value 0.000000.
# TOPOSORT: Optimize destination fix previous solution with value 0.000000.
# Running TOPOSORT with (1) Alpha points=0.540000 (2) Duals from by
# TOPOSORT: Toposort found solution with value 0.000000.
# TOPOSORT: Optimize destination fix previous solution with value 0.000000.
# Running TOPOSORT with (1) Alpha points=0.560000 (2) Original obj.
# TOPOSORT: Toposort found solution with value 0.000000.
# TOPOSORT: Optimize destination fix previous solution with value 0.000000.
# Running TOPOSORT with (1) Alpha points=0.560000 (2) Discounted original obj.
# TOPOSORT: Toposort found solution with value 0.000000.
# TOPOSORT: Optimize destination fix previous solution with value 0.000000.
# Running TOPOSORT with (1) Alpha points=0.560000 (2) Duals from by
# TOPOSORT: Toposort found solution with value 0.000000.
# TOPOSORT: Optimize destination fix previous solution with value 0.000000.
# Running TOPOSORT with (1) Alpha points=0.580000 (2) Original obj.
# TOPOSORT: Toposort found solution with value 0.000000.
# TOPOSORT: Optimize destination fix previous solution with value 0.000000.
# Running TOPOSORT with (1) Alpha points=0.580000 (2) Discounted original obj.
# TOPOSORT: Toposort found solution with value 0.000000.
# TOPOSORT: Optimize destination fix previous solution with value 0.000000.
# Running TOPOSORT with (1) Alpha points=0.580000 (2) Duals from by
# TOPOSORT: Toposort found solution with value 0.000000.
# TOPOSORT: Optimize destination fix previous solution with value 0.000000.
# Running TOPOSORT with (1) Alpha points=0.600000 (2) Original obj.
# TOPOSORT: Toposort found solution with value 0.000000.
# TOPOSORT: Optimize destination fix previous solution with value 0.000000.
# Running TOPOSORT with (1) Alpha points=0.600000 (2) Discounted original obj.
# TOPOSORT: Toposort found solution with value 0.000000.
# TOPOSORT: Optimize destination fix previous solution with value 0.000000.
# Running TOPOSORT with (1) Alpha points=0.600000 (2) Duals from by
# TOPOSORT: Toposort found solution with value 0.000000.
# TOPOSORT: Optimize destination fix previous solution with value 0.000000.
# Running TOPOSORT with (1) Alpha points=0.620000 (2) Original obj.
# TOPOSORT: Toposort found solution with value 0.000000.
# TOPOSORT: Optimize destination fix previous solution with value 0.000000.
# Running TOPOSORT with (1) Alpha points=0.620000 (2) Discounted original obj.
# TOPOSORT: Toposort found solution with value 0.000000.
# TOPOSORT: Optimize destination fix previous solution with value 0.000000.
# Running TOPOSORT with (1) Alpha points=0.620000 (2) Duals from by
# TOPOSORT: Toposort found solution with value 0.000000.
# TOPOSORT: Optimize destination fix previous solution with value 0.000000.
# Running TOPOSORT with (1) Alpha points=0.640000 (2) Original obj.
# TOPOSORT: Toposort found solution with value 0.000000.
# TOPOSORT: Optimize destination fix previous solution with value 0.000000.
# Running TOPOSORT with (1) Alpha points=0.640000 (2) Discounted original obj.
# TOPOSORT: Toposort found solution with value 0.000000.
# TOPOSORT: Optimize destination fix previous solution with value 0.000000.
# Running TOPOSORT with (1) Alpha points=0.640000 (2) Duals from by
# TOPOSORT: Toposort found solution with value 0.000000.
# TOPOSORT: Optimize destination fix previous solution with value 0.000000.
# Running TOPOSORT with (1) Alpha points=0.660000 (2) Original obj.
# TOPOSORT: Toposort found solution with value 0.000000.
# TOPOSORT: Optimize destination fix previous solution with value 0.000000.
# Running TOPOSORT with (1) Alpha points=0.660000 (2) Discounted original obj.
# TOPOSORT: Toposort found solution with value 0.000000.
# TOPOSORT: Optimize destination fix previous solution with value 0.000000.
# Running TOPOSORT with (1) Alpha points=0.660000 (2) Duals from by
# TOPOSORT: Toposort found solution with value 0.000000.
# TOPOSORT: Optimize destination fix previous solution with value 0.000000.
# Running TOPOSORT with (1) Alpha points=0.680000 (2) Original obj.
# TOPOSORT: Toposort found solution with value 0.000000.
# TOPOSORT: Optimize destination fix previous solution with value 0.000000.
# Running TOPOSORT with (1) Alpha points=0.680000 (2) Discounted original obj.
# TOPOSORT: Toposort found solution with value 0.000000.
# TOPOSORT: Optimize destination fix previous solution with value 0.000000.
# Running TOPOSORT with (1) Alpha points=0.680000 (2) Duals from by
# TOPOSORT: Toposort found solution with value 0.000000.
# TOPOSORT: Optimize destination fix previous solution with value 0.000000.
# Running TOPOSORT with (1) Alpha points=0.700000 (2) Original obj.
# TOPOSORT: Toposort found solution with value 0.000000.
# TOPOSORT: Optimize destination fix previous solution with value 0.000000.
# Running TOPOSORT with (1) Alpha points=0.700000 (2) Discounted original obj.
# TOPOSORT: Toposort found solution with value 0.000000.
# TOPOSORT: Optimize destination fix previous solution with value 0.000000.
# Running TOPOSORT with (1) Alpha points=0.700000 (2) Duals from by
# TOPOSORT: Toposort found solution with value 0.000000.
# TOPOSORT: Optimize destination fix previous solution with value 0.000000.
# Running TOPOSORT with (1) Alpha points=0.720000 (2) Original obj.
# TOPOSORT: Toposort found solution with value 0.000000.
# TOPOSORT: Optimize destination fix previous solution with value 0.000000.
# Running TOPOSORT with (1) Alpha points=0.720000 (2) Discounted original obj.
# TOPOSORT: Toposort found solution with value 0.000000.
# TOPOSORT: Optimize destination fix previous solution with value 0.000000.
# Running TOPOSORT with (1) Alpha points=0.720000 (2) Duals from by
# TOPOSORT: Toposort found solution with value 0.000000.
# TOPOSORT: Optimize destination fix previous solution with value 0.000000.
# Running TOPOSORT with (1) Alpha points=0.740000 (2) Original obj.
# TOPOSORT: Toposort found solution with value 0.000000.
# TOPOSORT: Optimize destination fix previous solution with value 0.000000.
# Running TOPOSORT with (1) Alpha points=0.740000 (2) Discounted original obj.
# TOPOSORT: Toposort found solution with value 0.000000.
# TOPOSORT: Optimize destination fix previous solution with value 0.000000.
# Running TOPOSORT with (1) Alpha points=0.740000 (2) Duals from by
# TOPOSORT: Toposort found solution with value 0.000000.
# TOPOSORT: Optimize destination fix previous solution with value 0.000000.
# Running TOPOSORT with (1) Alpha points=0.760000 (2) Original obj.
# TOPOSORT: Toposort found solution with value 0.000000.
# TOPOSORT: Optimize destination fix previous solution with value 0.000000.
# Running TOPOSORT with (1) Alpha points=0.760000 (2) Discounted original obj.
# TOPOSORT: Toposort found solution with value 0.000000.
# TOPOSORT: Optimize destination fix previous solution with value 0.000000.
# Running TOPOSORT with (1) Alpha points=0.760000 (2) Duals from by
# TOPOSORT: Toposort found solution with value 0.000000.
# TOPOSORT: Optimize destination fix previous solution with value 0.000000.
# Running TOPOSORT with (1) Alpha points=0.780000 (2) Original obj.
# TOPOSORT: Toposort found solution with value 0.000000.
# TOPOSORT: Optimize destination fix previous solution with value 0.000000.
# Running TOPOSORT with (1) Alpha points=0.780000 (2) Discounted original obj.
# TOPOSORT: Toposort found solution with value 0.000000.
# TOPOSORT: Optimize destination fix previous solution with value 0.000000.
# Running TOPOSORT with (1) Alpha points=0.780000 (2) Duals from by
# TOPOSORT: Toposort found solution with value 0.000000.
# TOPOSORT: Optimize destination fix previous solution with value 0.000000.
# Running TOPOSORT with (1) Alpha points=0.800000 (2) Original obj.
# TOPOSORT: Toposort found solution with value 0.000000.
# TOPOSORT: Optimize destination fix previous solution with value 0.000000.
# Running TOPOSORT with (1) Alpha points=0.800000 (2) Discounted original obj.
# TOPOSORT: Toposort found solution with value 0.000000.
# TOPOSORT: Optimize destination fix previous solution with value 0.000000.
# Running TOPOSORT with (1) Alpha points=0.800000 (2) Duals from by
# TOPOSORT: Toposort found solution with value 0.000000.
# TOPOSORT: Optimize destination fix previous solution with value 0.000000.
# Running TOPOSORT with (1) Alpha points=0.820000 (2) Original obj.
# TOPOSORT: Toposort found solution with value 0.000000.
# TOPOSORT: Optimize destination fix previous solution with value 0.000000.
# Running TOPOSORT with (1) Alpha points=0.820000 (2) Discounted original obj.
# TOPOSORT: Toposort found solution with value 0.000000.
# TOPOSORT: Optimize destination fix previous solution with value 0.000000.
# Running TOPOSORT with (1) Alpha points=0.820000 (2) Duals from by
# TOPOSORT: Toposort found solution with value 0.000000.
# TOPOSORT: Optimize destination fix previous solution with value 0.000000.
# Running TOPOSORT with (1) Alpha points=0.840000 (2) Original obj.
# TOPOSORT: Toposort found solution with value 0.000000.
# TOPOSORT: Optimize destination fix previous solution with value 0.000000.
# Running TOPOSORT with (1) Alpha points=0.840000 (2) Discounted original obj.
# TOPOSORT: Toposort found solution with value 0.000000.
# TOPOSORT: Optimize destination fix previous solution with value 0.000000.
# Running TOPOSORT with (1) Alpha points=0.840000 (2) Duals from by
# TOPOSORT: Toposort found solution with value 0.000000.
# TOPOSORT: Optimize destination fix previous solution with value 0.000000.
# Running TOPOSORT with (1) Alpha points=0.860000 (2) Original obj.
# TOPOSORT: Toposort found solution with value 0.000000.
# TOPOSORT: Optimize destination fix previous solution with value 0.000000.
# Running TOPOSORT with (1) Alpha points=0.860000 (2) Discounted original obj.
# TOPOSORT: Toposort found solution with value 0.000000.
# TOPOSORT: Optimize destination fix previous solution with value 0.000000.
# Running TOPOSORT with (1) Alpha points=0.860000 (2) Duals from by
# TOPOSORT: Toposort found solution with value 0.000000.
# TOPOSORT: Optimize destination fix previous solution with value 0.000000.
# Running TOPOSORT with (1) Alpha points=0.880000 (2) Original obj.
# TOPOSORT: Toposort found solution with value 0.000000.
# TOPOSORT: Optimize destination fix previous solution with value 0.000000.
# Running TOPOSORT with (1) Alpha points=0.880000 (2) Discounted original obj.
# TOPOSORT: Toposort found solution with value 0.000000.
# TOPOSORT: Optimize destination fix previous solution with value 0.000000.
# Running TOPOSORT with (1) Alpha points=0.880000 (2) Duals from by
# TOPOSORT: Toposort found solution with value 0.000000.
# TOPOSORT: Optimize destination fix previous solution with value 0.000000.
# Running TOPOSORT with (1) Alpha points=0.900000 (2) Original obj.
# TOPOSORT: Toposort found solution with value 0.000000.
# TOPOSORT: Optimize destination fix previous solution with value 0.000000.
# Running TOPOSORT with (1) Alpha points=0.900000 (2) Discounted original obj.
# TOPOSORT: Toposort found solution with value 0.000000.
# TOPOSORT: Optimize destination fix previous solution with value 0.000000.
# Running TOPOSORT with (1) Alpha points=0.900000 (2) Duals from by
# TOPOSORT: Toposort found solution with value 0.000000.
# TOPOSORT: Optimize destination fix previous solution with value 0.000000.
# Running TOPOSORT with (1) Alpha points=0.920000 (2) Original obj.
# TOPOSORT: Toposort found solution with value 0.000000.
# TOPOSORT: Optimize destination fix previous solution with value 0.000000.
# Running TOPOSORT with (1) Alpha points=0.920000 (2) Discounted original obj.
# TOPOSORT: Toposort found solution with value 0.000000.
# TOPOSORT: Optimize destination fix previous solution with value 0.000000.
# Running TOPOSORT with (1) Alpha points=0.920000 (2) Duals from by
# TOPOSORT: Toposort found solution with value 0.000000.
# TOPOSORT: Optimize destination fix previous solution with value 0.000000.
# Running TOPOSORT with (1) Alpha points=0.940000 (2) Original obj.
# TOPOSORT: Toposort found solution with value 0.000000.
# TOPOSORT: Optimize destination fix previous solution with value 0.000000.
# Running TOPOSORT with (1) Alpha points=0.940000 (2) Discounted original obj.
# TOPOSORT: Toposort found solution with value 0.000000.
# TOPOSORT: Optimize destination fix previous solution with value 0.000000.
# Running TOPOSORT with (1) Alpha points=0.940000 (2) Duals from by
# TOPOSORT: Toposort found solution with value 0.000000.
# TOPOSORT: Optimize destination fix previous solution with value 0.000000.
# Running TOPOSORT with (1) Alpha points=0.960000 (2) Original obj.
# TOPOSORT: Toposort found solution with value 0.000000.
# TOPOSORT: Optimize destination fix previous solution with value 0.000000.
# Running TOPOSORT with (1) Alpha points=0.960000 (2) Discounted original obj.
# TOPOSORT: Toposort found solution with value 0.000000.
# TOPOSORT: Optimize destination fix previous solution with value 0.000000.
# Running TOPOSORT with (1) Alpha points=0.960000 (2) Duals from by
# TOPOSORT: Toposort found solution with value 0.000000.
# TOPOSORT: Optimize destination fix previous solution with value 0.000000.
# Running TOPOSORT with (1) Alpha points=0.980000 (2) Original obj.
# TOPOSORT: Toposort found solution with value 0.000000.
# TOPOSORT: Optimize destination fix previous solution with value 0.000000.
# Running TOPOSORT with (1) Alpha points=0.980000 (2) Discounted original obj.
# TOPOSORT: Toposort found solution with value 0.000000.
# TOPOSORT: Optimize destination fix previous solution with value 0.000000.
# Running TOPOSORT with (1) Alpha points=0.980000 (2) Duals from by
# TOPOSORT: Toposort found solution with value 0.000000.
# TOPOSORT: Optimize destination fix previous solution with value 0.000000.
# Running TOPOSORT with (1) Alpha points=1.000000 (2) Original obj.
# TOPOSORT: Toposort found solution with value 0.000000.
# TOPOSORT: Optimize destination fix previous solution with value 0.000000.
# Running TOPOSORT with (1) Alpha points=1.000000 (2) Discounted original obj.
# TOPOSORT: Toposort found solution with value 0.000000.
# TOPOSORT: Optimize destination fix previous solution with value 0.000000.
# Running TOPOSORT with (1) Alpha points=1.000000 (2) Duals from by
# TOPOSORT: Toposort found solution with value 0.000000.
# TOPOSORT: Optimize destination fix previous solution with value 0.000000.
# STATS_TOPOSORT_OBJVAL 0.000000
# STATS_TOPOSORT_TIME 0.019631
#
#
#           |------------------------------------------------------------|
#           |       TOPOSORT SOLUTION QUALITY INFORMATION                |
#           |------------------------------------------------------------|
#           |                                | PP-AGG Sol  |  Orig Sol   |
#           |--------------------------------+-------------+-------------|
#           | Const. violation (max 3.0e+05) |  3.0482e+08 |  3.0482e+08 |
#           | Prec violation   (max 1.0e-05) |  0.0000e+00 |  0.0000e+00 |
#           | Bounds violation (max 1.0e-05) | -0.0000e+00 | -0.0000e+00 |
#           | Is Feasible?                   |     No      |     No      |
#           |--------------------------------+-------------+-------------|
#           | W. Int. Viol.    (max 1.0e-02) |  0.0000e+00 |  0.0000e+00 |
#           | S. Int. Viol.    (max 1.0e-02) |  0.0000e+00 |  0.0000e+00 |
#           | Is Integer (weak)?             |     Yes     |     Yes     |
#           | Is Integer (strong)?           |     Yes     |     Yes     |
#           |--------------------------------+-------------+-------------|
#           | Objective Value                |  0.0000e+00 |  0.0000e+00 |
#           |--------------------------------+-------------+-------------|
#           | Best Previous LP Solution      |-1.7977e+308 |  6.6729e+08 |
#           | Replace Best LP Solution?      |     No      |     No      |
#           |------------------------------------------------------------|
#           | Best Previous IP Solution      |-1.7977e+308 |-1.7977e+308 |
#           | Replace Best IP Solution?      |     No      |     No      |
#           |--------------------------------+-------------+-------------|
#           | Best known Upper Bound         |             |-1.7977e+308 |
#           | Integrality Gap                |             |    -100.0%   |
#           |------------------------------------------------------------|
#
#           |------+------------------+---------+---------|
#           |  t   |    Objval[t]     | Perc[t] |  Acc[t] |
#           |------+------------------+---------+---------|
#           |------+------------------+---------+---------|
#           | tot  |           0.0000 | 100.00% | 100.00% |
#           |------+------------------+---------+---------|
#
#
# |-----+--------------------------------+--------------------------------+--------------------------------|
# |  t  |         CONSTRAINT:  0         |         CONSTRAINT:  1         |         CONSTRAINT:  2         |
# |-----+--------------------------------+--------------------------------+--------------------------------|
# |-----+--------------------------------+--------------------------------+--------------------------------|
#
#
#
# Done with Toposort in 0.025397 seconds. Time elapsed: 0.050376 in orsolver_internal (/home/nloira/projects/OMP/src/orsolver.c:1636)
#
# Done with Optimize Destination in 0.000000 seconds. Time elapsed: 0.050378 in orsolver_internal (/home/nloira/projects/OMP/src/orsolver.c:1718)
# Not performing naive heuristic
#
# Done with Naive in 0.000000 seconds. Time elapsed: 0.050381 in orsolver_internal (/home/nloira/projects/OMP/src/orsolver.c:1837)
#
# Done with CP in 0.000000 seconds. Time elapsed: 0.050382 in orsolver_internal (/home/nloira/projects/OMP/src/orsolver.c:1987)
# STATS_HEURISTICS_OBJVAL 0.000000
# STATS_HEURISTICS_TIME 0.025404
#
# Done with ORSOLVER in 0.050384 seconds. in orsolver_internal (/home/nloira/projects/OMP/src/orsolver.c:2241)
#
# HEADER: name param nbins_orig nblocks_orig ndest_orig nperiods_orig narcs_orig nbins_pp nblocks_pp ndestinations_pp nperiods_pp narcs_pp nconstraints nidx_at_orig nidx_at_pp nidx_by_pp time_input_testing time_preprocessing time_aggregation time_init_structs time_input_sol time_hotstart time_cuts time_LP time_topo time_naive time_rtw time_bb time_cp total_time cg_master_time cg_pricing_time cg_iterations bz_out_npartitions out_npartitions_bz out_nrounds_rootcp bb_niter lp_objval_orig lp_objval_pp lp_ubound ip_objval_orig ip_objval_pp ip_ubound toposort_objval naive_objval naive_od_objval rtw_objval
#
# SUMMARY: openPit_openPit_dbs_duals ../FilesToExecuteOmpOpenPit/params/dbs_duals.params 11760 11760 1 5 53312 848 848 1 5 3150 7 58800 3894 3894 0.000727 0.005590 0.000001 0.000566 0.000000 0.006691 0.000002 0.011384 0.025397 0.000000 0.000000 0.000000 0.000000 0.050384 0.002566 0.002215 3 44 0 0 0 667290078.347125 * * * * * 0.000000 * * *
#
#
# Finished OMP-ORSOLVER in 0.062708 seconds.
#
# STATS_TOTAL_TIME 0.062710

# %%
import re

pi_positions = [positions.start() for positions in re.finditer("rhs= 0.000000", output)]
pi_t = dict.fromkeys(openPitModel.t_C,0)
for pos in pi_positions:
    pi_value = float(output[pos-48: pos].split()[-3])
    pi_index = float(output[pos-48: pos].split()[-5])
    period_index = pi_index - openPitModel.numberOfPeriods * (openPitModel.numberOfConstraints - 1)
    pi_t[period_index] = pi_value

objective_value_positions = [positions.start() for positions in re.finditer("Objective Value ", output)]
objective_value = float(output[objective_value_positions[0]: objective_value_positions[0]+100].split()[-3])

objective_value, pi_t
# Out:
# (667290000.0, {0: 0, 1: 0, 2: 0, 3: 0, 4: 4096.0})

# %%
output[objective_value_positions[0]: objective_value_positions[0]+100].split()
# Out:
# ['Objective',
#  'Value',
#  '|',
#  '6.6729e+08',
#  '|',
#  '6.6729e+08',
#  '|',
#  '|----------------------------']

# %%
a = output[pos-48: pos].split()
b = int(a[-5])
a
# Out:
# ['00', 'BZ_DUAL:', 'row=', '34', 'pi=', '4096.000000', 'sense=', 'L']

# %%
index
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In [12], line 1
# ----> 1 index
#
# NameError: name 'index' is not defined

# %%
pi_t
# Out:
# {0: 0, 1: 0, 2: 0, 3: 0, 4: 5662813.786159}

# %%
a = numberOfPeriods * (7 - 1)#30
b = (numberOfPeriods * 7) -1#34

b-a
# Out:
# 4
